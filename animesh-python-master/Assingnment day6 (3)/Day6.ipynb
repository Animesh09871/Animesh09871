# %%
# Reading Joining_status

import csv
import pandas as pd
import matplotlib.pyplot as plt

with open('Joining_Status.csv','r')as file_to_read:
    data=csv.reader(file_to_read)
    for i in data:
        print(i)
# Out:
# ['Candidate_Ref', 'Status']
# ['2110407', 'Joined']
# ['2112635', 'Joined']
# ['2112838', 'Joined']
# ['2115021', 'Joined']
# ['2115125', 'Joined']
# ['2117167', 'Joined']
# ['2119124', 'Joined']
# ['2127572', 'Joined']
# ['2138169', 'Joined']
# ['2143362', 'Joined']
# ['2151180', 'Not Joined']
# ['2154264', 'Joined']
# ['2156236', 'Not Joined']
# ['2158703', 'Not Joined']
# ['2161257', 'Not Joined']
# ['2162487', 'Joined']
# ['2166041', 'Not Joined']
# ['2172982', 'Joined']
# ['2173730', 'Joined']
# ['2175237', 'Joined']
# ['2175323', 'Joined']
# ['2184108', 'Joined']
# ['2188014', 'Joined']
# ['2191237', 'Joined']
# ['2194323', 'Joined']
# ['2205244', 'Not Joined']
# ['2205496', 'Joined']
# ['2207823', 'Joined']
# ['2211699', 'Not Joined']
# ['2214217', 'Joined']
# ['2214446', 'Joined']
# ['2221643', 'Joined']
# ['2221707', 'Not Joined']
# ['2222480', 'Not Joined']
# ['2222936', 'Joined']
# ['2223040', 'Joined']
# ['2224425', 'Joined']
# ['2224426', 'Joined']
# ['2225685', 'Joined']
# ['2226215', 'Joined']
# ['2227339', 'Not Joined']
# ['2227431', 'Joined']
# ['2233506', 'Joined']
# ['2237763', 'Joined']
# ['2237899', 'Joined']
# ['2238751', 'Not Joined']
# ['2238809', 'Not Joined']
# ['2245529', 'Not Joined']
# ['2281509', 'Joined']
# ['2282688', 'Joined']
# ['2282703', 'Joined']
# ['2283257', 'Joined']
# ['2286200', 'Not Joined']
# ['2286297', 'Joined']
# ['2286317', 'Joined']
# ['2286381', 'Joined']
# ['2286467', 'Joined']
# ['2286651', 'Joined']
# ['2287263', 'Not Joined']
# ['2287314', 'Joined']
# ['2301543', 'Joined']
# ['2302202', 'Joined']
# ['2322849', 'Not Joined']
# ['2322986', 'Joined']
# ['2328123', 'Joined']
# ['2328443', 'Joined']
# ['2344484', 'Not Joined']
# ['2347819', 'Joined']
# ['2348220', 'Joined']
# ['2351625', 'Joined']
# ['2351866', 'Joined']
# ['2352045', 'Joined']
# ['2352237', 'Joined']
# ['2354362', 'Joined']
# ['2356737', 'Joined']
# ['2361174', 'Not Joined']
# ['2364321', 'Joined']
# ['2364483', 'Joined']
# ['2364616', 'Joined']
# ['2365129', 'Not Joined']
# ['2368400', 'Joined']
# ['2368563', 'Joined']
# ['2372840', 'Joined']
# ['2377978', 'Joined']
# ['2377993', 'Joined']
# ['2378003', 'Joined']
# ['2378097', 'Joined']
# ['2378111', 'Joined']
# ['2378829', 'Joined']
# ['2382818', 'Not Joined']
# ['2383202', 'Joined']
# ['2398717', 'Joined']
# ['2400028', 'Not Joined']
# ['2403871', 'Joined']
# ['2407721', 'Joined']
# ['2416792', 'Joined']
# ['2417836', 'Joined']
# ['2419759', 'Joined']
# ['2424526', 'Joined']
# ['2437820', 'Joined']
# ['2440646', 'Joined']
# ['2440672', 'Joined']
# ['2440753', 'Not Joined']
# ['2441165', 'Joined']
# ['2441279', 'Not Joined']
# ['2442101', 'Joined']
# ['2444384', 'Not Joined']
# ['2444496', 'Not Joined']
# ['2445042', 'Joined']
# ['2452418', 'Joined']
# ['2452436', 'Joined']
# ['2457480', 'Joined']
# ['2458879', 'Joined']
# ['2461027', 'Joined']
# ['2461696', 'Joined']
# ['2464247', 'Not Joined']
# ['2464457', 'Joined']
# ['2464782', 'Joined']
# ['2468663', 'Joined']
# ['2468764', 'Joined']
# ['2473555', 'Joined']
# ['2474614', 'Joined']
# ['2474728', 'Not Joined']
# ['2474750', 'Joined']
# ['2478398', 'Joined']
# ['2478695', 'Joined']
# ['2479005', 'Not Joined']
# ['2480992', 'Joined']
# ['2481514', 'Joined']
# ['2483538', 'Joined']
# ['2537835', 'Joined']
# ['2537925', 'Joined']
# ['2537986', 'Not Joined']
# ['2544512', 'Joined']
# ['2556458', 'Joined']
# ['2561022', 'Joined']
# ['2561128', 'Joined']
# ['2564986', 'Joined']
# ['2569520', 'Joined']
# ['2575776', 'Joined']
# ['2576352', 'Joined']
# ['2586163', 'Joined']
# ['2586868', 'Joined']
# ['2590178', 'Joined']
# ['2590903', 'Joined']
# ['2591263', 'Joined']
# ['2591495', 'Joined']
# ['2593939', 'Not Joined']
# ['2594486', 'Joined']
# ['2594579', 'Joined']
# ['2598011', 'Joined']
# ['2598184', 'Joined']
# ['2600880', 'Joined']
# ['2605197', 'Joined']
# ['2609241', 'Joined']
# ['2609287', 'Not Joined']
# ['2613516', 'Not Joined']
# ['2613742', 'Joined']
# ['2615966', 'Not Joined']
# ['2618791', 'Joined']
# ['2635381', 'Joined']
# ['2635429', 'Joined']
# ['2635526', 'Joined']
# ['2635705', 'Joined']
# ['2635749', 'Joined']
# ['2778998', 'Joined']
# ['2780352', 'Joined']
# ['2780669', 'Not Joined']
# ['2780903', 'Joined']
# ['2781322', 'Joined']
# ['2786502', 'Joined']
# ['2790302', 'Joined']
# ['2793776', 'Joined']
# ['2794614', 'Joined']
# ['2795222', 'Not Joined']
# ['2802356', 'Joined']
# ['2804650', 'Joined']
# ['2807929', 'Joined']
# ['2814312', 'Joined']
# ['2814340', 'Joined']
# ['2814452', 'Joined']
# ['2819665', 'Joined']
# ['2819712', 'Joined']
# ['2823905', 'Joined']
# ['2824103', 'Joined']
# ['2826712', 'Joined']
# ['2828770', 'Joined']
# ['2828841', 'Joined']
# ['2834484', 'Joined']
# ['2834603', 'Joined']
# ['2839728', 'Joined']
# ['2840929', 'Joined']
# ['2841169', 'Joined']
# ['2845533', 'Joined']
# ['2845929', 'Joined']
# ['2846059', 'Not Joined']
# ['2850795', 'Joined']
# ['2850802', 'Joined']
# ['2861481', 'Joined']
# ['2861532', 'Joined']
# ['2861816', 'Joined']
# ['2861873', 'Not Joined']
# ['2861938', 'Not Joined']
# ['2863789', 'Joined']
# ['2865940', 'Joined']
# ['2866433', 'Joined']
# ['2926304', 'Not Joined']
# ['2930426', 'Not Joined']
# ['2945577', 'Joined']
# ['3029497', 'Joined']
# ['3029512', 'Joined']
# ['3030928', 'Joined']
# ['3034334', 'Not Joined']
# ['3034476', 'Joined']
# ['3034980', 'Not Joined']
# ['3037418', 'Joined']
# ['3040819', 'Joined']
# ['3046539', 'Joined']
# ['3046652', 'Joined']
# ['3108736', 'Joined']
# ['3110300', 'Joined']
# ['3120254', 'Not Joined']
# ['3188371', 'Joined']
# ['3200275', 'Joined']
# ['3200724', 'Joined']
# ['3203880', 'Joined']
# ['3204472', 'Joined']
# ['3211382', 'Joined']
# ['3211556', 'Joined']
# ['3215106', 'Joined']
# ['3215514', 'Joined']
# ['3215757', 'Joined']
# ['3221299', 'Joined']
# ['3225344', 'Joined']
# ['3225955', 'Not Joined']
# ['3225969', 'Joined']
# ['3226137', 'Joined']
# ['3226180', 'Joined']
# ['3229762', 'Joined']
# ['3234247', 'Not Joined']
# ['3238748', 'Joined']
# ['3239288', 'Joined']
# ['3243075', 'Joined']
# ['3244438', 'Joined']
# ['3245861', 'Joined']
# ['3245971', 'Joined']
# ['3250021', 'Joined']
# ['3250029', 'Not Joined']
# ['3250143', 'Joined']
# ['3250941', 'Not Joined']
# ['3251306', 'Joined']
# ['3256827', 'Joined']
# ['3257382', 'Not Joined']
# ['3257556', 'Joined']
# ['3257972', 'Joined']
# ['3258076', 'Not Joined']
# ['3258078', 'Joined']
# ['3258105', 'Joined']
# ['3258125', 'Joined']
# ['3262701', 'Joined']
# ['3263017', 'Not Joined']
# ['3264071', 'Joined']
# ['3267491', 'Joined']
# ['3267878', 'Not Joined']
# ['3267960', 'Joined']
# ['3272381', 'Not Joined']
# ['3278272', 'Joined']
# ['3280954', 'Joined']
# ['3283933', 'Joined']
# ['3284172', 'Not Joined']
# ['3284288', 'Joined']
# ['3288600', 'Joined']
# ['3290646', 'Not Joined']
# ['3293535', 'Joined']
# ['3293720', 'Joined']
# ['3294274', 'Joined']
# ['3294297', 'Joined']
# ['3294316', 'Joined']
# ['3294384', 'Joined']
# ['3300178', 'Joined']
# ['3300192', 'Joined']
# ['3300563', 'Joined']
# ['3300715', 'Joined']
# ['3300802', 'Joined']
# ['3300828', 'Joined']
# ['3302340', 'Joined']
# ['3304533', 'Joined']
# ['3305244', 'Joined']
# ['3311520', 'Not Joined']
# ['3318393', 'Joined']
# ['3321416', 'Joined']
# ['3322390', 'Joined']
# ['3327789', 'Joined']
# ['3327838', 'Joined']
# ['3328005', 'Joined']
# ['3328526', 'Joined']
# ['3328640', 'Not Joined']
# ['3338018', 'Joined']
# ['3342223', 'Joined']
# ['3342678', 'Joined']
# ['3346442', 'Joined']
# ['3347772', 'Joined']
# ['3347826', 'Joined']
# ['3348191', 'Joined']
# ['3351261', 'Not Joined']
# ['3351640', 'Joined']
# ['3351807', 'Joined']
# ['3351848', 'Joined']
# ['3352340', 'Joined']
# ['3355586', 'Joined']
# ['3355597', 'Joined']
# ['3356490', 'Joined']
# ['3356959', 'Joined']
# ['3374169', 'Joined']
# ['3374257', 'Not Joined']
# ['3377182', 'Joined']
# ['3377286', 'Joined']
# ['3377474', 'Joined']
# ['3379707', 'Not Joined']
# ['3379843', 'Not Joined']
# ['3382002', 'Joined']
# ['3382722', 'Joined']
# ['3418495', 'Joined']
# ['3423899', 'Joined']
# ['3423964', 'Joined']
# ['3424007', 'Joined']
# ['3424549', 'Not Joined']
# ['3424789', 'Joined']
# ['3425046', 'Joined']
# ['3428591', 'Not Joined']
# ['3429009', 'Joined']
# ['3429992', 'Joined']
# ['3435024', 'Joined']
# ['3458547', 'Joined']
# ['3459128', 'Joined']
# ['3459132', 'Joined']
# ['3462905', 'Joined']
# ['3463459', 'Joined']
# ['3470343', 'Joined']
# ['3470957', 'Joined']
# ['3476331', 'Joined']
# ['3488358', 'Joined']
# ['3495740', 'Joined']
# ['3507312', 'Not Joined']
# ['3512053', 'Joined']
# ['3518153', 'Joined']
# ['3538488', 'Joined']
# ['3538610', 'Joined']
# ['3544532', 'Not Joined']
# ['3587994', 'Joined']
# ['3618730', 'Joined']
# ['3618909', 'Joined']
# ['3619135', 'Joined']
# ['3631656', 'Joined']
# ['3632340', 'Joined']
# ['3644811', 'Joined']
# ['3649761', 'Joined']
# ['3664507', 'Joined']
# ['3671120', 'Joined']
# ['3685301', 'Joined']
# ['3685332', 'Not Joined']
# ['3685353', 'Joined']
# ['3685392', 'Joined']
# ['3685427', 'Joined']
# ['3687244', 'Joined']
# ['3697401', 'Joined']
# ['3699033', 'Not Joined']
# ['3707268', 'Joined']
# ['3709298', 'Joined']
# ['3727916', 'Joined']
# ['3758183', 'Joined']
# ['3815047', 'Joined']
# ['3828911', 'Joined']
# ['2109586', 'Joined']
# ['2109941', 'Joined']
# ['2110719', 'Not Joined']
# ['2111873', 'Joined']
# ['2111978', 'Not Joined']
# ['2112613', 'Joined']
# ['2112944', 'Joined']
# ['2113310', 'Joined']
# ['2113315', 'Joined']
# ['2113885', 'Joined']
# ['2114740', 'Joined']
# ['2114758', 'Joined']
# ['2114973', 'Joined']
# ['2115688', 'Joined']
# ['2115820', 'Joined']
# ['2115908', 'Joined']
# ['2115986', 'Not Joined']
# ['2116452', 'Joined']
# ['2116640', 'Joined']
# ['2116851', 'Joined']
# ['2116859', 'Joined']
# ['2117309', 'Joined']
# ['2117762', 'Joined']
# ['2117808', 'Joined']
# ['2117861', 'Joined']
# ['2117896', 'Joined']
# ['2117921', 'Joined']
# ['2117926', 'Joined']
# ['2118024', 'Joined']
# ['2118139', 'Joined']
# ['2118193', 'Not Joined']
# ['2118300', 'Joined']
# ['2118473', 'Joined']
# ['2118480', 'Joined']
# ['2118610', 'Joined']
# ['2118630', 'Joined']
# ['2118716', 'Joined']
# ['2118805', 'Joined']
# ['2118878', 'Joined']
# ['2119296', 'Joined']
# ['2119360', 'Joined']
# ['2119541', 'Joined']
# ['2119655', 'Joined']
# ['2119874', 'Joined']
# ['2120133', 'Not Joined']
# ['2120232', 'Joined']
# ['2120258', 'Joined']
# ['2120572', 'Joined']
# ['2120791', 'Joined']
# ['2120897', 'Joined']
# ['2120920', 'Not Joined']
# ['2121031', 'Joined']
# ['2121112', 'Joined']
# ['2121207', 'Joined']
# ['2121527', 'Joined']
# ['2122391', 'Joined']
# ['2122623', 'Joined']
# ['2122706', 'Joined']
# ['2123227', 'Not Joined']
# ['2123270', 'Joined']
# ['2123719', 'Joined']
# ['2123913', 'Joined']
# ['2124670', 'Joined']
# ['2124683', 'Joined']
# ['2125000', 'Joined']
# ['2125046', 'Joined']
# ['2125244', 'Joined']
# ['2125838', 'Joined']
# ['2126303', 'Joined']
# ['2126389', 'Joined']
# ['2126878', 'Not Joined']
# ['2127041', 'Joined']
# ['2127782', 'Joined']
# ['2128251', 'Joined']
# ['2128352', 'Joined']
# ['2128469', 'Joined']
# ['2128714', 'Joined']
# ['2129464', 'Not Joined']
# ['2129601', 'Joined']
# ['2130101', 'Joined']
# ['2130730', 'Not Joined']
# ['2130753', 'Joined']
# ['2130839', 'Not Joined']
# ['2130922', 'Not Joined']
# ['2131204', 'Joined']
# ['2131246', 'Joined']
# ['2131535', 'Not Joined']
# ['2131616', 'Joined']
# ['2131676', 'Joined']
# ['2131733', 'Joined']
# ['2131968', 'Joined']
# ['2132737', 'Joined']
# ['2133665', 'Joined']
# ['2133747', 'Joined']
# ['2133758', 'Joined']
# ['2134039', 'Not Joined']
# ['2134381', 'Not Joined']
# ['2134817', 'Joined']
# ['2134959', 'Joined']
# ['2136278', 'Joined']
# ['2136315', 'Joined']
# ['2136567', 'Joined']
# ['2136958', 'Not Joined']
# ['2138445', 'Joined']
# ['2138471', 'Joined']
# ['2138841', 'Joined']
# ['2139136', 'Joined']
# ['2140585', 'Joined']
# ['2140793', 'Not Joined']
# ['2143355', 'Joined']
# ['2143448', 'Joined']
# ['2143686', 'Joined']
# ['2143765', 'Joined']
# ['2143770', 'Joined']
# ['2144272', 'Joined']
# ['2144343', 'Joined']
# ['2144825', 'Joined']
# ['2145173', 'Joined']
# ['2145517', 'Joined']
# ['2145771', 'Joined']
# ['2146026', 'Joined']
# ['2146469', 'Joined']
# ['2146807', 'Joined']
# ['2146927', 'Joined']
# ['2147122', 'Joined']
# ['2147297', 'Joined']
# ['2147302', 'Joined']
# ['2147577', 'Joined']
# ['2147590', 'Joined']
# ['2147859', 'Not Joined']
# ['2147964', 'Joined']
# ['2148210', 'Joined']
# ['2148332', 'Joined']
# ['2148336', 'Joined']
# ['2148378', 'Joined']
# ['2148538', 'Joined']
# ['2148558', 'Joined']
# ['2148752', 'Joined']
# ['2148836', 'Joined']
# ['2149085', 'Joined']
# ['2149106', 'Joined']
# ['2149123', 'Joined']
# ['2149651', 'Joined']
# ['2149658', 'Joined']
# ['2149743', 'Joined']
# ['2149768', 'Joined']
# ['2149945', 'Joined']
# ['2150099', 'Joined']
# ['2150660', 'Joined']
# ['2150789', 'Joined']
# ['2150946', 'Joined']
# ['2151025', 'Joined']
# ['2151039', 'Joined']
# ['2151137', 'Joined']
# ['2151591', 'Joined']
# ['2151611', 'Joined']
# ['2152130', 'Joined']
# ['2152217', 'Joined']
# ['2152453', 'Joined']
# ['2152543', 'Joined']
# ['2152579', 'Joined']
# ['2152769', 'Not Joined']
# ['2153190', 'Joined']
# ['2153344', 'Joined']
# ['2154259', 'Joined']
# ['2154545', 'Joined']
# ['2154726', 'Joined']
# ['2154884', 'Joined']
# ['2154907', 'Joined']
# ['2154909', 'Joined']
# ['2154912', 'Joined']
# ['2154921', 'Joined']
# ['2154979', 'Joined']
# ['2155052', 'Joined']
# ['2155155', 'Joined']
# ['2155289', 'Not Joined']
# ['2155393', 'Joined']
# ['2155686', 'Joined']
# ['2155774', 'Joined']
# ['2155777', 'Joined']
# ['2155870', 'Joined']
# ['2156090', 'Joined']
# ['2156448', 'Joined']
# ['2156459', 'Not Joined']
# ['2156763', 'Joined']
# ['2156826', 'Joined']
# ['2156827', 'Joined']
# ['2156877', 'Joined']
# ['2157107', 'Joined']
# ['2157115', 'Joined']
# ['2157132', 'Not Joined']
# ['2158015', 'Joined']
# ['2158209', 'Joined']
# ['2158413', 'Joined']
# ['2158843', 'Joined']
# ['2158995', 'Joined']
# ['2159450', 'Not Joined']
# ['2159511', 'Joined']
# ['2159833', 'Joined']
# ['2159838', 'Joined']
# ['2160044', 'Joined']
# ['2160046', 'Not Joined']
# ['2160082', 'Not Joined']
# ['2160132', 'Joined']
# ['2160319', 'Joined']
# ['2160352', 'Joined']
# ['2160481', 'Joined']
# ['2160552', 'Joined']
# ['2160605', 'Not Joined']
# ['2160861', 'Joined']
# ['2160947', 'Joined']
# ['2161281', 'Joined']
# ['2161467', 'Not Joined']
# ['2161504', 'Joined']
# ['2161845', 'Joined']
# ['2162269', 'Joined']
# ['2162503', 'Joined']
# ['2162935', 'Joined']
# ['2163132', 'Joined']
# ['2163175', 'Joined']
# ['2163284', 'Joined']
# ['2163368', 'Joined']
# ['2163575', 'Joined']
# ['2163723', 'Joined']
# ['2164010', 'Joined']
# ['2164318', 'Joined']
# ['2164359', 'Joined']
# ['2164737', 'Joined']
# ['2164746', 'Joined']
# ['2164811', 'Not Joined']
# ['2165168', 'Joined']
# ['2165190', 'Not Joined']
# ['2165199', 'Joined']
# ['2165286', 'Joined']
# ['2165445', 'Joined']
# ['2165812', 'Not Joined']
# ['2166010', 'Not Joined']
# ['2166380', 'Joined']
# ['2166511', 'Joined']
# ['2166676', 'Joined']
# ['2166822', 'Joined']
# ['2167220', 'Joined']
# ['2167555', 'Joined']
# ['2167868', 'Joined']
# ['2167973', 'Not Joined']
# ['2168323', 'Joined']
# ['2168387', 'Joined']
# ['2168583', 'Joined']
# ['2168773', 'Joined']
# ['2169589', 'Joined']
# ['2169623', 'Not Joined']
# ['2169631', 'Joined']
# ['2169842', 'Joined']
# ['2169873', 'Joined']
# ['2169991', 'Joined']
# ['2170117', 'Joined']
# ['2170209', 'Joined']
# ['2170273', 'Joined']
# ['2170379', 'Joined']
# ['2170460', 'Joined']
# ['2170535', 'Joined']
# ['2170647', 'Joined']
# ['2170735', 'Not Joined']
# ['2171021', 'Joined']
# ['2171091', 'Joined']
# ['2171108', 'Joined']
# ['2171315', 'Joined']
# ['2171367', 'Joined']
# ['2171465', 'Not Joined']
# ['2171501', 'Joined']
# ['2171677', 'Joined']
# ['2171814', 'Joined']
# ['2172103', 'Joined']
# ['2172167', 'Joined']
# ['2172847', 'Not Joined']
# ['2172869', 'Not Joined']
# ['2172971', 'Joined']
# ['2173123', 'Joined']
# ['2173398', 'Joined']
# ['2173534', 'Joined']
# ['2173551', 'Joined']
# ['2173671', 'Joined']
# ['2173909', 'Joined']
# ['2174437', 'Joined']
# ['2174468', 'Joined']
# ['2174971', 'Joined']
# ['2175038', 'Joined']
# ['2175130', 'Joined']
# ['2175243', 'Joined']
# ['2175474', 'Joined']
# ['2175602', 'Joined']
# ['2175902', 'Joined']
# ['2176574', 'Joined']
# ['2176613', 'Joined']
# ['2176764', 'Joined']
# ['2176768', 'Joined']
# ['2177093', 'Joined']
# ['2177281', 'Joined']
# ['2177421', 'Joined']
# ['2177539', 'Not Joined']
# ['2177575', 'Joined']
# ['2177940', 'Joined']
# ['2178561', 'Joined']
# ['2178570', 'Joined']
# ['2178642', 'Joined']
# ['2178776', 'Joined']
# ['2178863', 'Joined']
# ['2178970', 'Joined']
# ['2179012', 'Joined']
# ['2179114', 'Joined']
# ['2179353', 'Joined']
# ['2179394', 'Joined']
# ['2179445', 'Joined']
# ['2179498', 'Joined']
# ['2179527', 'Joined']
# ['2179588', 'Joined']
# ['2179606', 'Joined']
# ['2179672', 'Not Joined']
# ['2179820', 'Not Joined']
# ['2179918', 'Joined']
# ['2179990', 'Joined']
# ['2180100', 'Joined']
# ['2180139', 'Joined']
# ['2180161', 'Joined']
# ['2180284', 'Joined']
# ['2180317', 'Joined']
# ['2180334', 'Joined']
# ['2180560', 'Not Joined']
# ['2180598', 'Joined']
# ['2180658', 'Joined']
# ['2180940', 'Joined']
# ['2181066', 'Not Joined']
# ['2181092', 'Joined']
# ['2181439', 'Not Joined']
# ['2181617', 'Joined']
# ['2181704', 'Joined']
# ['2181750', 'Joined']
# ['2181792', 'Joined']
# ['2181793', 'Not Joined']
# ['2181814', 'Joined']
# ['2181937', 'Joined']
# ['2182197', 'Joined']
# ['2182277', 'Joined']
# ['2182596', 'Joined']
# ['2182618', 'Joined']
# ['2182825', 'Not Joined']
# ['2182884', 'Joined']
# ['2182990', 'Joined']
# ['2183010', 'Joined']
# ['2183130', 'Joined']
# ['2183143', 'Joined']
# ['2183379', 'Joined']
# ['2183551', 'Joined']
# ['2183846', 'Joined']
# ['2183879', 'Joined']
# ['2183901', 'Joined']
# ['2183991', 'Joined']
# ['2184018', 'Joined']
# ['2184148', 'Joined']
# ['2184198', 'Joined']
# ['2184331', 'Joined']
# ['2184345', 'Joined']
# ['2184452', 'Not Joined']
# ['2184706', 'Joined']
# ['2184717', 'Joined']
# ['2184967', 'Joined']
# ['2185071', 'Joined']
# ['2185459', 'Joined']
# ['2185479', 'Joined']
# ['2185780', 'Joined']
# ['2185799', 'Joined']
# ['2185971', 'Joined']
# ['2186155', 'Joined']
# ['2186204', 'Joined']
# ['2186215', 'Joined']
# ['2186241', 'Not Joined']
# ['2186450', 'Joined']
# ['2186483', 'Joined']
# ['2186494', 'Joined']
# ['2186869', 'Joined']
# ['2186972', 'Not Joined']
# ['2186986', 'Joined']
# ['2187024', 'Joined']
# ['2187044', 'Joined']
# ['2187095', 'Joined']
# ['2187112', 'Joined']
# ['2187308', 'Joined']
# ['2187355', 'Joined']
# ['2187545', 'Joined']
# ['2187585', 'Joined']
# ['2187601', 'Joined']
# ['2187626', 'Joined']
# ['2187635', 'Joined']
# ['2187705', 'Joined']
# ['2187909', 'Not Joined']
# ['2187922', 'Joined']
# ['2188037', 'Joined']
# ['2188162', 'Joined']
# ['2188617', 'Joined']
# ['2188640', 'Joined']
# ['2188661', 'Not Joined']
# ['2189313', 'Not Joined']
# ['2189391', 'Joined']
# ['2189472', 'Joined']
# ['2189480', 'Joined']
# ['2189503', 'Joined']
# ['2189516', 'Joined']
# ['2189775', 'Not Joined']
# ['2189875', 'Joined']
# ['2189953', 'Not Joined']
# ['2190520', 'Joined']
# ['2190646', 'Joined']
# ['2190682', 'Joined']
# ['2190763', 'Joined']
# ['2191532', 'Joined']
# ['2191843', 'Joined']
# ['2191902', 'Joined']
# ['2191924', 'Joined']
# ['2191964', 'Joined']
# ['2192001', 'Joined']
# ['2192105', 'Joined']
# ['2192448', 'Joined']
# ['2192493', 'Not Joined']
# ['2192534', 'Joined']
# ['2192552', 'Joined']
# ['2192768', 'Joined']
# ['2192769', 'Joined']
# ['2192824', 'Not Joined']
# ['2193319', 'Joined']
# ['2193372', 'Joined']
# ['2193455', 'Joined']
# ['2193459', 'Not Joined']
# ['2193568', 'Joined']
# ['2193595', 'Joined']
# ['2193699', 'Not Joined']
# ['2194047', 'Joined']
# ['2194144', 'Joined']
# ['2194172', 'Joined']
# ['2194191', 'Joined']
# ['2194204', 'Joined']
# ['2194281', 'Joined']
# ['2194367', 'Joined']
# ['2194465', 'Not Joined']
# ['2194506', 'Joined']
# ['2194577', 'Joined']
# ['2194682', 'Joined']
# ['2194924', 'Joined']
# ['2194965', 'Joined']
# ['2195069', 'Joined']
# ['2195146', 'Joined']
# ['2195330', 'Joined']
# ['2195338', 'Joined']
# ['2195344', 'Joined']
# ['2195455', 'Joined']
# ['2195484', 'Joined']
# ['2195573', 'Joined']
# ['2195869', 'Joined']
# ['2195878', 'Joined']
# ['2195901', 'Joined']
# ['2195905', 'Not Joined']
# ['2195916', 'Joined']
# ['2195946', 'Joined']
# ['2196106', 'Joined']
# ['2196142', 'Joined']
# ['2196199', 'Joined']
# ['2196396', 'Joined']
# ['2196462', 'Joined']
# ['2196497', 'Joined']
# ['2196505', 'Joined']
# ['2196570', 'Joined']
# ['2196595', 'Joined']
# ['2196666', 'Joined']
# ['2196742', 'Joined']
# ['2196744', 'Not Joined']
# ['2196951', 'Joined']
# ['2197020', 'Joined']
# ['2197145', 'Joined']
# ['2197160', 'Not Joined']
# ['2197234', 'Not Joined']
# ['2197275', 'Joined']
# ['2197288', 'Joined']
# ['2197324', 'Joined']
# ['2197385', 'Joined']
# ['2197405', 'Joined']
# ['2197475', 'Joined']
# ['2197741', 'Not Joined']
# ['2197955', 'Joined']
# ['2198174', 'Not Joined']
# ['2198224', 'Joined']
# ['2198231', 'Not Joined']
# ['2198517', 'Not Joined']
# ['2199018', 'Joined']
# ['2199160', 'Joined']
# ['2199208', 'Joined']
# ['2199313', 'Joined']
# ['2199638', 'Joined']
# ['2199641', 'Joined']
# ['2199770', 'Not Joined']
# ['2199791', 'Joined']
# ['2199853', 'Joined']
# ['2199904', 'Joined']
# ['2200077', 'Joined']
# ['2200088', 'Joined']
# ['2200173', 'Joined']
# ['2200307', 'Joined']
# ['2200444', 'Not Joined']
# ['2200753', 'Joined']
# ['2200806', 'Joined']
# ['2200924', 'Joined']
# ['2201006', 'Joined']
# ['2201012', 'Joined']
# ['2201057', 'Joined']
# ['2201082', 'Joined']
# ['2201161', 'Joined']
# ['2201479', 'Joined']
# ['2201794', 'Not Joined']
# ['2201885', 'Joined']
# ['2201998', 'Not Joined']
# ['2202103', 'Joined']
# ['2202337', 'Not Joined']
# ['2202344', 'Joined']
# ['2202349', 'Joined']
# ['2202409', 'Not Joined']
# ['2202421', 'Joined']
# ['2203413', 'Joined']
# ['2203590', 'Joined']
# ['2203667', 'Joined']
# ['2203772', 'Joined']
# ['2204272', 'Joined']
# ['2204314', 'Joined']
# ['2205130', 'Not Joined']
# ['2205274', 'Joined']
# ['2205314', 'Not Joined']
# ['2205396', 'Not Joined']
# ['2205424', 'Joined']
# ['2205587', 'Joined']
# ['2205928', 'Joined']
# ['2206061', 'Joined']
# ['2206089', 'Joined']
# ['2206093', 'Joined']
# ['2206103', 'Joined']
# ['2206266', 'Joined']
# ['2206306', 'Joined']
# ['2206399', 'Not Joined']
# ['2206428', 'Joined']
# ['2206561', 'Joined']
# ['2206613', 'Joined']
# ['2206671', 'Not Joined']
# ['2206858', 'Joined']
# ['2207080', 'Joined']
# ['2207120', 'Joined']
# ['2207154', 'Joined']
# ['2207185', 'Joined']
# ['2207227', 'Joined']
# ['2207390', 'Joined']
# ['2207475', 'Joined']
# ['2207654', 'Not Joined']
# ['2207674', 'Joined']
# ['2207703', 'Joined']
# ['2207746', 'Not Joined']
# ['2207768', 'Joined']
# ['2207825', 'Joined']
# ['2207826', 'Joined']
# ['2207841', 'Joined']
# ['2207871', 'Joined']
# ['2207912', 'Joined']
# ['2207929', 'Joined']
# ['2207946', 'Not Joined']
# ['2207961', 'Joined']
# ['2208075', 'Joined']
# ['2208298', 'Joined']
# ['2208305', 'Joined']
# ['2208477', 'Not Joined']
# ['2208506', 'Joined']
# ['2208656', 'Joined']
# ['2208864', 'Joined']
# ['2208967', 'Not Joined']
# ['2209120', 'Joined']
# ['2209208', 'Joined']
# ['2209220', 'Not Joined']
# ['2209238', 'Not Joined']
# ['2209384', 'Joined']
# ['2209414', 'Not Joined']
# ['2209470', 'Joined']
# ['2209525', 'Joined']
# ['2209959', 'Joined']
# ['2209977', 'Not Joined']
# ['2209983', 'Joined']
# ['2210045', 'Joined']
# ['2210065', 'Joined']
# ['2210105', 'Joined']
# ['2210229', 'Joined']
# ['2210822', 'Joined']
# ['2210993', 'Joined']
# ['2211010', 'Joined']
# ['2211230', 'Joined']
# ['2211244', 'Joined']
# ['2211281', 'Joined']
# ['2211315', 'Joined']
# ['2211359', 'Joined']
# ['2211401', 'Joined']
# ['2211419', 'Joined']
# ['2211433', 'Joined']
# ['2211544', 'Joined']
# ['2211632', 'Joined']
# ['2211634', 'Joined']
# ['2211702', 'Joined']
# ['2211793', 'Joined']
# ['2211859', 'Not Joined']
# ['2212112', 'Joined']
# ['2212125', 'Joined']
# ['2212226', 'Not Joined']
# ['2212249', 'Not Joined']
# ['2212284', 'Joined']
# ['2212289', 'Joined']
# ['2212291', 'Not Joined']
# ['2212302', 'Joined']
# ['2212306', 'Joined']
# ['2212344', 'Joined']
# ['2212529', 'Joined']
# ['2212607', 'Joined']
# ['2212671', 'Joined']
# ['2212739', 'Joined']
# ['2212755', 'Joined']
# ['2212769', 'Joined']
# ['2212796', 'Joined']
# ['2212828', 'Joined']
# ['2212858', 'Joined']
# ['2212924', 'Joined']
# ['2212981', 'Joined']
# ['2213307', 'Not Joined']
# ['2213314', 'Joined']
# ['2213349', 'Joined']
# ['2213389', 'Joined']
# ['2213394', 'Joined']
# ['2213469', 'Joined']
# ['2213524', 'Joined']
# ['2213551', 'Joined']
# ['2213699', 'Not Joined']
# ['2213768', 'Joined']
# ['2213882', 'Joined']
# ['2213957', 'Joined']
# ['2213974', 'Joined']
# ['2214024', 'Joined']
# ['2214038', 'Joined']
# ['2214096', 'Joined']
# ['2214157', 'Joined']
# ['2214384', 'Joined']
# ['2214434', 'Joined']
# ['2214522', 'Not Joined']
# ['2214537', 'Joined']
# ['2214556', 'Joined']
# ['2214582', 'Joined']
# ['2214616', 'Joined']
# ['2214624', 'Joined']
# ['2214746', 'Not Joined']
# ['2214818', 'Joined']
# ['2214852', 'Joined']
# ['2214855', 'Joined']
# ['2214864', 'Joined']
# ['2214871', 'Joined']
# ['2214980', 'Joined']
# ['2215134', 'Joined']
# ['2215313', 'Joined']
# ['2215317', 'Joined']
# ['2215376', 'Joined']
# ['2215403', 'Joined']
# ['2215484', 'Joined']
# ['2215517', 'Joined']
# ['2215636', 'Joined']
# ['2215744', 'Joined']
# ['2215762', 'Joined']
# ['2215778', 'Not Joined']
# ['2215812', 'Joined']
# ['2215906', 'Joined']
# ['2216007', 'Joined']
# ['2216029', 'Joined']
# ['2216175', 'Not Joined']
# ['2216200', 'Joined']
# ['2216477', 'Not Joined']
# ['2216486', 'Joined']
# ['2216568', 'Joined']
# ['2216607', 'Joined']
# ['2216642', 'Joined']
# ['2216668', 'Not Joined']
# ['2216838', 'Joined']
# ['2216997', 'Joined']
# ['2217096', 'Not Joined']
# ['2217119', 'Not Joined']
# ['2217138', 'Joined']
# ['2217146', 'Joined']
# ['2217246', 'Joined']
# ['2217251', 'Not Joined']
# ['2217261', 'Not Joined']
# ['2217338', 'Joined']
# ['2217540', 'Joined']
# ['2217543', 'Joined']
# ['2217614', 'Joined']
# ['2217626', 'Joined']
# ['2217668', 'Joined']
# ['2217818', 'Joined']
# ['2217840', 'Joined']
# ['2217898', 'Not Joined']
# ['2217908', 'Joined']
# ['2217921', 'Joined']
# ['2217929', 'Joined']
# ['2217977', 'Not Joined']
# ['2218090', 'Joined']
# ['2218110', 'Joined']
# ['2218158', 'Joined']
# ['2218189', 'Joined']
# ['2218193', 'Joined']
# ['2218234', 'Joined']
# ['2218251', 'Not Joined']
# ['2218336', 'Joined']
# ['2218339', 'Joined']
# ['2218343', 'Joined']
# ['2218696', 'Joined']
# ['2218721', 'Joined']
# ['2218748', 'Joined']
# ['2218750', 'Joined']
# ['2218789', 'Not Joined']
# ['2219025', 'Joined']
# ['2219059', 'Joined']
# ['2219061', 'Not Joined']
# ['2219069', 'Not Joined']
# ['2219159', 'Joined']
# ['2219327', 'Joined']
# ['2219362', 'Not Joined']
# ['2219378', 'Joined']
# ['2219450', 'Joined']
# ['2219472', 'Not Joined']
# ['2219532', 'Joined']
# ['2219601', 'Joined']
# ['2219603', 'Not Joined']
# ['2219686', 'Not Joined']
# ['2219816', 'Joined']
# ['2219868', 'Joined']
# ['2219880', 'Joined']
# ['2219986', 'Joined']
# ['2220030', 'Joined']
# ['2220133', 'Joined']
# ['2220200', 'Joined']
# ['2220282', 'Joined']
# ['2220334', 'Joined']
# ['2220454', 'Joined']
# ['2220465', 'Joined']
# ['2220477', 'Joined']
# ['2220489', 'Joined']
# ['2220770', 'Joined']
# ['2220795', 'Joined']
# ['2220806', 'Joined']
# ['2220849', 'Joined']
# ['2220858', 'Joined']
# ['2221002', 'Joined']
# ['2221020', 'Joined']
# ['2221131', 'Not Joined']
# ['2221147', 'Not Joined']
# ['2221149', 'Joined']
# ['2221152', 'Joined']
# ['2221170', 'Joined']
# ['2221192', 'Joined']
# ['2221231', 'Joined']
# ['2221289', 'Joined']
# ['2221397', 'Joined']
# ['2221477', 'Joined']
# ['2221576', 'Joined']
# ['2221586', 'Joined']
# ['2221838', 'Joined']
# ['2221849', 'Not Joined']
# ['2221870', 'Joined']
# ['2221883', 'Joined']
# ['2221895', 'Joined']
# ['2222019', 'Not Joined']
# ['2222124', 'Joined']
# ['2222151', 'Joined']
# ['2222381', 'Joined']
# ['2222383', 'Joined']
# ['2222418', 'Joined']
# ['2222513', 'Not Joined']
# ['2222527', 'Not Joined']
# ['2222537', 'Joined']
# ['2222583', 'Joined']
# ['2222597', 'Joined']
# ['2222607', 'Joined']
# ['2222656', 'Joined']
# ['2222684', 'Joined']
# ['2222753', 'Joined']
# ['2222760', 'Joined']
# ['2222811', 'Joined']
# ['2222862', 'Not Joined']
# ['2222876', 'Joined']
# ['2223049', 'Joined']
# ['2223201', 'Not Joined']
# ['2223277', 'Joined']
# ['2223478', 'Joined']
# ['2223526', 'Not Joined']
# ['2223638', 'Joined']
# ['2223724', 'Joined']
# ['2223780', 'Joined']
# ['2223850', 'Joined']
# ['2223906', 'Not Joined']
# ['2223946', 'Joined']
# ['2224105', 'Joined']
# ['2224118', 'Joined']
# ['2224129', 'Not Joined']
# ['2224193', 'Joined']
# ['2224233', 'Joined']
# ['2224244', 'Joined']
# ['2224332', 'Not Joined']
# ['2224384', 'Joined']
# ['2224457', 'Joined']
# ['2224512', 'Joined']
# ['2224876', 'Joined']
# ['2225053', 'Joined']
# ['2225098', 'Joined']
# ['2225100', 'Joined']
# ['2225111', 'Joined']
# ['2225144', 'Joined']
# ['2225176', 'Joined']
# ['2225215', 'Joined']
# ['2225216', 'Joined']
# ['2225236', 'Joined']
# ['2225237', 'Joined']
# ['2225254', 'Joined']
# ['2225270', 'Joined']
# ['2225359', 'Joined']
# ['2225375', 'Joined']
# ['2225377', 'Joined']
# ['2225392', 'Joined']
# ['2225445', 'Joined']
# ['2225463', 'Joined']
# ['2225482', 'Not Joined']
# ['2225515', 'Joined']
# ['2225524', 'Joined']
# ['2225537', 'Joined']
# ['2225580', 'Joined']
# ['2225711', 'Joined']
# ['2225731', 'Joined']
# ['2225771', 'Not Joined']
# ['2225793', 'Joined']
# ['2225807', 'Joined']
# ['2225924', 'Joined']
# ['2225958', 'Joined']
# ['2226059', 'Joined']
# ['2226216', 'Joined']
# ['2226270', 'Joined']
# ['2226279', 'Joined']
# ['2226315', 'Joined']
# ['2226400', 'Joined']
# ['2226443', 'Joined']
# ['2226489', 'Joined']
# ['2226546', 'Joined']
# ['2226552', 'Joined']
# ['2226569', 'Joined']
# ['2226605', 'Not Joined']
# ['2226679', 'Joined']
# ['2226694', 'Joined']
# ['2226739', 'Joined']
# ['2226789', 'Joined']
# ['2226829', 'Joined']
# ['2226839', 'Joined']
# ['2226868', 'Joined']
# ['2226988', 'Joined']
# ['2227004', 'Joined']
# ['2227007', 'Not Joined']
# ['2227033', 'Not Joined']
# ['2227119', 'Not Joined']
# ['2227145', 'Joined']
# ['2227158', 'Joined']
# ['2227169', 'Joined']
# ['2227172', 'Joined']
# ['2227197', 'Joined']
# ['2227198', 'Joined']
# ['2227371', 'Joined']
# ['2227381', 'Joined']
# ['2227563', 'Joined']
# ['2227630', 'Joined']
# ['2227682', 'Joined']
# ['2228335', 'Joined']
# ['2228955', 'Not Joined']
# ['2229287', 'Joined']
# ['2229362', 'Joined']
# ['2229526', 'Joined']
# ['2229527', 'Not Joined']
# ['2229614', 'Joined']
# ['2229645', 'Joined']
# ['2230421', 'Not Joined']
# ['2230827', 'Not Joined']
# ['2230930', 'Joined']
# ['2231438', 'Joined']
# ['2231493', 'Not Joined']
# ['2231530', 'Joined']
# ['2231561', 'Joined']
# ['2232310', 'Joined']
# ['2232835', 'Not Joined']
# ['2233088', 'Joined']
# ['2233137', 'Joined']
# ['2233511', 'Joined']
# ['2233530', 'Joined']
# ['2233700', 'Not Joined']
# ['2234187', 'Joined']
# ['2234424', 'Joined']
# ['2234459', 'Not Joined']
# ['2234726', 'Joined']
# ['2235336', 'Not Joined']
# ['2235809', 'Not Joined']
# ['2235998', 'Joined']
# ['2236082', 'Joined']
# ['2236306', 'Joined']
# ['2236369', 'Joined']
# ['2236380', 'Joined']
# ['2236465', 'Joined']
# ['2236739', 'Joined']
# ['2237720', 'Joined']
# ['2238088', 'Not Joined']
# ['2238662', 'Joined']
# ['2239130', 'Joined']
# ['2239150', 'Not Joined']
# ['2239367', 'Joined']
# ['2239647', 'Joined']
# ['2239750', 'Joined']
# ['2240669', 'Joined']
# ['2240823', 'Joined']
# ['2240919', 'Joined']
# ['2241021', 'Not Joined']
# ['2241124', 'Not Joined']
# ['2241289', 'Not Joined']
# ['2241394', 'Joined']
# ['2241432', 'Joined']
# ['2241540', 'Joined']
# ['2241564', 'Joined']
# ['2241649', 'Not Joined']
# ['2241897', 'Not Joined']
# ['2242358', 'Not Joined']
# ['2242995', 'Joined']
# ['2243583', 'Joined']
# ['2243975', 'Not Joined']
# ['2244070', 'Not Joined']
# ['2244749', 'Joined']
# ['2245537', 'Joined']
# ['2245778', 'Joined']
# ['2246064', 'Joined']
# ['2246102', 'Joined']
# ['2246619', 'Joined']
# ['2246656', 'Joined']
# ['2246667', 'Joined']
# ['2246675', 'Joined']
# ['2246688', 'Not Joined']
# ['2246749', 'Joined']
# ['2246864', 'Joined']
# ['2246905', 'Joined']
# ['2247230', 'Joined']
# ['2247238', 'Joined']
# ['2247281', 'Joined']
# ['2247348', 'Joined']
# ['2247434', 'Joined']
# ['2247552', 'Not Joined']
# ['2247596', 'Joined']
# ['2247661', 'Joined']
# ['2247698', 'Joined']
# ['2247703', 'Joined']
# ['2247722', 'Joined']
# ['2247754', 'Joined']
# ['2247783', 'Joined']
# ['2247811', 'Joined']
# ['2247845', 'Not Joined']
# ['2248268', 'Joined']
# ['2248284', 'Joined']
# ['2248595', 'Joined']
# ['2265448', 'Joined']
# ['2265531', 'Joined']
# ['2265573', 'Not Joined']
# ['2277584', 'Joined']
# ['2279859', 'Joined']
# ['2280155', 'Joined']
# ['2280495', 'Joined']
# ['2280699', 'Joined']
# ['2280791', 'Joined']
# ['2280811', 'Not Joined']
# ['2280925', 'Joined']
# ['2280982', 'Joined']
# ['2280985', 'Joined']
# ['2280999', 'Joined']
# ['2281013', 'Joined']
# ['2281059', 'Joined']
# ['2281133', 'Not Joined']
# ['2281153', 'Joined']
# ['2281164', 'Joined']
# ['2281166', 'Not Joined']
# ['2281196', 'Not Joined']
# ['2281214', 'Joined']
# ['2281237', 'Joined']
# ['2281322', 'Joined']
# ['2281326', 'Joined']
# ['2281348', 'Joined']
# ['2281360', 'Joined']
# ['2281368', 'Joined']
# ['2281370', 'Not Joined']
# ['2281418', 'Joined']
# ['2281420', 'Joined']
# ['2281423', 'Joined']
# ['2281432', 'Joined']
# ['2281465', 'Joined']
# ['2281487', 'Joined']
# ['2281506', 'Not Joined']
# ['2281513', 'Joined']
# ['2281541', 'Joined']
# ['2281558', 'Joined']
# ['2281575', 'Joined']
# ['2281605', 'Joined']
# ['2281611', 'Joined']
# ['2281616', 'Joined']
# ['2281624', 'Joined']
# ['2281646', 'Joined']
# ['2281657', 'Joined']
# ['2281661', 'Joined']
# ['2281669', 'Joined']
# ['2281671', 'Joined']
# ['2281676', 'Joined']
# ['2281683', 'Joined']
# ['2281687', 'Joined']
# ['2281689', 'Joined']
# ['2281713', 'Joined']
# ['2281719', 'Joined']
# ['2281720', 'Joined']
# ['2281722', 'Joined']
# ['2281725', 'Joined']
# ['2281726', 'Joined']
# ['2281728', 'Joined']
# ['2281734', 'Joined']
# ['2281758', 'Joined']
# ['2281773', 'Joined']
# ['2281781', 'Joined']
# ['2281791', 'Joined']
# ['2281796', 'Joined']
# ['2281798', 'Joined']
# ['2281802', 'Not Joined']
# ['2281815', 'Joined']
# ['2281818', 'Joined']
# ['2281828', 'Joined']
# ['2281830', 'Joined']
# ['2281849', 'Joined']
# ['2281854', 'Joined']
# ['2281865', 'Joined']
# ['2281870', 'Joined']
# ['2281876', 'Joined']
# ['2281879', 'Joined']
# ['2281916', 'Joined']
# ['2281925', 'Joined']
# ['2282009', 'Joined']
# ['2282012', 'Joined']
# ['2282027', 'Joined']
# ['2282029', 'Joined']
# ['2282038', 'Joined']
# ['2282053', 'Joined']
# ['2282056', 'Joined']
# ['2282063', 'Joined']
# ['2282065', 'Joined']
# ['2282074', 'Joined']
# ['2282076', 'Joined']
# ['2282078', 'Joined']
# ['2282082', 'Joined']
# ['2282086', 'Joined']
# ['2282091', 'Joined']
# ['2282095', 'Joined']
# ['2282100', 'Joined']
# ['2282115', 'Joined']
# ['2282162', 'Joined']
# ['2282185', 'Not Joined']
# ['2282191', 'Joined']
# ['2282193', 'Joined']
# ['2282199', 'Joined']
# ['2282210', 'Joined']
# ['2282228', 'Not Joined']
# ['2282234', 'Joined']
# ['2282238', 'Joined']
# ['2282274', 'Joined']
# ['2282282', 'Joined']
# ['2282285', 'Joined']
# ['2282298', 'Joined']
# ['2282307', 'Not Joined']
# ['2282320', 'Joined']
# ['2282323', 'Joined']
# ['2282347', 'Joined']
# ['2282360', 'Joined']
# ['2282409', 'Not Joined']
# ['2282418', 'Joined']
# ['2282433', 'Joined']
# ['2282461', 'Joined']
# ['2282496', 'Joined']
# ['2282502', 'Joined']
# ['2282504', 'Not Joined']
# ['2282508', 'Joined']
# ['2282557', 'Joined']
# ['2282572', 'Joined']
# ['2282585', 'Joined']
# ['2282604', 'Not Joined']
# ['2282641', 'Joined']
# ['2282669', 'Joined']
# ['2282744', 'Joined']
# ['2282841', 'Joined']
# ['2282856', 'Joined']
# ['2282880', 'Joined']
# ['2282902', 'Joined']
# ['2282995', 'Joined']
# ['2283028', 'Not Joined']
# ['2283037', 'Joined']
# ['2283076', 'Joined']
# ['2283111', 'Not Joined']
# ['2283122', 'Joined']
# ['2283129', 'Joined']
# ['2283144', 'Joined']
# ['2283160', 'Joined']
# ['2283210', 'Joined']
# ['2283219', 'Joined']
# ['2283221', 'Joined']
# ['2283311', 'Joined']
# ['2283361', 'Not Joined']
# ['2283419', 'Joined']
# ['2283469', 'Joined']
# ['2283494', 'Not Joined']
# ['2283544', 'Joined']
# ['2283552', 'Joined']
# ['2283626', 'Joined']
# ['2283692', 'Joined']
# ['2283737', 'Joined']
# ['2283806', 'Joined']
# ['2283832', 'Joined']
# ['2283853', 'Not Joined']
# ['2283922', 'Not Joined']
# ['2283933', 'Joined']
# ['2283970', 'Joined']
# ['2284021', 'Joined']
# ['2284025', 'Joined']
# ['2284034', 'Not Joined']
# ['2284085', 'Joined']
# ['2284110', 'Joined']
# ['2284124', 'Joined']
# ['2284140', 'Joined']
# ['2284157', 'Joined']
# ['2284176', 'Not Joined']
# ['2284179', 'Joined']
# ['2284187', 'Joined']
# ['2284218', 'Joined']
# ['2284231', 'Joined']
# ['2284307', 'Joined']
# ['2284329', 'Joined']
# ['2284332', 'Joined']
# ['2284340', 'Joined']
# ['2284352', 'Joined']
# ['2284387', 'Joined']
# ['2284397', 'Joined']
# ['2284401', 'Joined']
# ['2284403', 'Joined']
# ['2284406', 'Joined']
# ['2284407', 'Not Joined']
# ['2284408', 'Joined']
# ['2284412', 'Joined']
# ['2284417', 'Joined']
# ['2284419', 'Joined']
# ['2284420', 'Not Joined']
# ['2284443', 'Not Joined']
# ['2284465', 'Joined']
# ['2284478', 'Joined']
# ['2284481', 'Joined']
# ['2284495', 'Joined']
# ['2284548', 'Joined']
# ['2284561', 'Joined']
# ['2284571', 'Joined']
# ['2284602', 'Joined']
# ['2284612', 'Joined']
# ['2284613', 'Joined']
# ['2284620', 'Not Joined']
# ['2284626', 'Joined']
# ['2284652', 'Not Joined']
# ['2284658', 'Joined']
# ['2284698', 'Joined']
# ['2284759', 'Not Joined']
# ['2284769', 'Joined']
# ['2284796', 'Joined']
# ['2284798', 'Not Joined']
# ['2284803', 'Joined']
# ['2284849', 'Joined']
# ['2284852', 'Not Joined']
# ['2284855', 'Joined']
# ['2284875', 'Joined']
# ['2284892', 'Joined']
# ['2284921', 'Joined']
# ['2284925', 'Joined']
# ['2284984', 'Joined']
# ['2285102', 'Joined']
# ['2285142', 'Joined']
# ['2285233', 'Not Joined']
# ['2285272', 'Joined']
# ['2285274', 'Joined']
# ['2285282', 'Joined']
# ['2285381', 'Not Joined']
# ['2285385', 'Not Joined']
# ['2285455', 'Not Joined']
# ['2285469', 'Joined']
# ['2285507', 'Not Joined']
# ['2285592', 'Joined']
# ['2285662', 'Joined']
# ['2285680', 'Joined']
# ['2285682', 'Joined']
# ['2285709', 'Joined']
# ['2285719', 'Joined']
# ['2285738', 'Joined']
# ['2285745', 'Joined']
# ['2285746', 'Joined']
# ['2285757', 'Joined']
# ['2285824', 'Joined']
# ['2285869', 'Joined']
# ['2285882', 'Joined']
# ['2285932', 'Joined']
# ['2285955', 'Joined']
# ['2286029', 'Joined']
# ['2286033', 'Joined']
# ['2286070', 'Joined']
# ['2286119', 'Joined']
# ['2286127', 'Joined']
# ['2286163', 'Joined']
# ['2286189', 'Joined']
# ['2286197', 'Joined']
# ['2286265', 'Joined']
# ['2286282', 'Joined']
# ['2286286', 'Not Joined']
# ['2286321', 'Joined']
# ['2286368', 'Joined']
# ['2286369', 'Joined']
# ['2286371', 'Not Joined']
# ['2286440', 'Joined']
# ['2286456', 'Joined']
# ['2286464', 'Joined']
# ['2286494', 'Joined']
# ['2286623', 'Joined']
# ['2286627', 'Joined']
# ['2286629', 'Joined']
# ['2286668', 'Joined']
# ['2286704', 'Not Joined']
# ['2286705', 'Joined']
# ['2286784', 'Joined']
# ['2286813', 'Joined']
# ['2286836', 'Joined']
# ['2286848', 'Joined']
# ['2286850', 'Joined']
# ['2286861', 'Joined']
# ['2286868', 'Joined']
# ['2286875', 'Joined']
# ['2286887', 'Joined']
# ['2286914', 'Joined']
# ['2286937', 'Joined']
# ['2287049', 'Joined']
# ['2287072', 'Joined']
# ['2287090', 'Joined']
# ['2287091', 'Joined']
# ['2287119', 'Joined']
# ['2287133', 'Joined']
# ['2287150', 'Joined']
# ['2287162', 'Joined']
# ['2287165', 'Joined']
# ['2287184', 'Joined']
# ['2287211', 'Joined']
# ['2287229', 'Not Joined']
# ['2287232', 'Joined']
# ['2287285', 'Not Joined']
# ['2287299', 'Joined']
# ['2287319', 'Joined']
# ['2287320', 'Joined']
# ['2287325', 'Joined']
# ['2287339', 'Joined']
# ['2291775', 'Joined']
# ['2291824', 'Joined']
# ['2293431', 'Joined']
# ['2294055', 'Joined']
# ['2294419', 'Joined']
# ['2297270', 'Joined']
# ['2297327', 'Not Joined']
# ['2297344', 'Not Joined']
# ['2297908', 'Not Joined']
# ['2297941', 'Joined']
# ['2298116', 'Joined']
# ['2298336', 'Joined']
# ['2298365', 'Joined']
# ['2298374', 'Joined']
# ['2301536', 'Joined']
# ['2301590', 'Not Joined']
# ['2301611', 'Joined']
# ['2301629', 'Joined']
# ['2301648', 'Joined']
# ['2301649', 'Joined']
# ['2301652', 'Joined']
# ['2301661', 'Joined']
# ['2301662', 'Joined']
# ['2301665', 'Joined']
# ['2301666', 'Joined']
# ['2301673', 'Not Joined']
# ['2301676', 'Joined']
# ['2301697', 'Joined']
# ['2301704', 'Joined']
# ['2301720', 'Joined']
# ['2302197', 'Joined']
# ['2302209', 'Not Joined']
# ['2302211', 'Joined']
# ['2302319', 'Joined']
# ['2302377', 'Joined']
# ['2302438', 'Joined']
# ['2302452', 'Joined']
# ['2302469', 'Not Joined']
# ['2302470', 'Joined']
# ['2302486', 'Joined']
# ['2303698', 'Not Joined']
# ['2309606', 'Not Joined']
# ['2309634', 'Joined']
# ['2309682', 'Joined']
# ['2309687', 'Joined']
# ['2309688', 'Joined']
# ['2309695', 'Not Joined']
# ['2309700', 'Joined']
# ['2309711', 'Joined']
# ['2309714', 'Joined']
# ['2309739', 'Joined']
# ['2309761', 'Not Joined']
# ['2309776', 'Joined']
# ['2309805', 'Joined']
# ['2309808', 'Joined']
# ['2309843', 'Joined']
# ['2309846', 'Joined']
# ['2309851', 'Joined']
# ['2309853', 'Joined']
# ['2309856', 'Joined']
# ['2309857', 'Joined']
# ['2309892', 'Joined']
# ['2309894', 'Joined']
# ['2309895', 'Joined']
# ['2309896', 'Joined']
# ['2309914', 'Joined']
# ['2309985', 'Joined']
# ['2310382', 'Joined']
# ['2311432', 'Joined']
# ['2311760', 'Joined']
# ['2312770', 'Joined']
# ['2314265', 'Joined']
# ['2314523', 'Joined']
# ['2318368', 'Joined']
# ['2318388', 'Not Joined']
# ['2322593', 'Not Joined']
# ['2322664', 'Joined']
# ['2322668', 'Joined']
# ['2322698', 'Joined']
# ['2322706', 'Not Joined']
# ['2322707', 'Joined']
# ['2322708', 'Joined']
# ['2322712', 'Joined']
# ['2322714', 'Joined']
# ['2322715', 'Joined']
# ['2322717', 'Joined']
# ['2322718', 'Joined']
# ['2322720', 'Joined']
# ['2322721', 'Joined']
# ['2322722', 'Joined']
# ['2322723', 'Joined']
# ['2322724', 'Joined']
# ['2322742', 'Not Joined']
# ['2322764', 'Not Joined']
# ['2322784', 'Not Joined']
# ['2322835', 'Joined']
# ['2322839', 'Not Joined']
# ['2322842', 'Not Joined']
# ['2322844', 'Joined']
# ['2322880', 'Joined']
# ['2322889', 'Joined']
# ['2322902', 'Joined']
# ['2322906', 'Joined']
# ['2322908', 'Not Joined']
# ['2322933', 'Joined']
# ['2323037', 'Joined']
# ['2323061', 'Not Joined']
# ['2323100', 'Joined']
# ['2323115', 'Joined']
# ['2323127', 'Joined']
# ['2323202', 'Not Joined']
# ['2323213', 'Not Joined']
# ['2323216', 'Not Joined']
# ['2323276', 'Joined']
# ['2323320', 'Joined']
# ['2323353', 'Not Joined']
# ['2323406', 'Joined']
# ['2323420', 'Joined']
# ['2323426', 'Joined']
# ['2325910', 'Joined']
# ['2325933', 'Joined']
# ['2326125', 'Joined']
# ['2326727', 'Joined']
# ['2327989', 'Joined']
# ['2328076', 'Joined']
# ['2328085', 'Not Joined']
# ['2328118', 'Joined']
# ['2328121', 'Joined']
# ['2328145', 'Joined']
# ['2328172', 'Joined']
# ['2328181', 'Joined']
# ['2328182', 'Joined']
# ['2328202', 'Not Joined']
# ['2328204', 'Joined']
# ['2328234', 'Joined']
# ['2328236', 'Joined']
# ['2328251', 'Not Joined']
# ['2328276', 'Joined']
# ['2328282', 'Joined']
# ['2328283', 'Joined']
# ['2328289', 'Not Joined']
# ['2328309', 'Joined']
# ['2328311', 'Joined']
# ['2328315', 'Not Joined']
# ['2328316', 'Joined']
# ['2328350', 'Joined']
# ['2328418', 'Joined']
# ['2328432', 'Joined']
# ['2328438', 'Not Joined']
# ['2328445', 'Joined']
# ['2328458', 'Joined']
# ['2328460', 'Joined']
# ['2328468', 'Not Joined']
# ['2328548', 'Joined']
# ['2328549', 'Joined']
# ['2328609', 'Joined']
# ['2328635', 'Joined']
# ['2328686', 'Joined']
# ['2330428', 'Joined']
# ['2340930', 'Joined']
# ['2340943', 'Not Joined']
# ['2340950', 'Not Joined']
# ['2340999', 'Joined']
# ['2341079', 'Joined']
# ['2341092', 'Joined']
# ['2341114', 'Joined']
# ['2341169', 'Joined']
# ['2341181', 'Joined']
# ['2341189', 'Joined']
# ['2341195', 'Joined']
# ['2341196', 'Joined']
# ['2341197', 'Not Joined']
# ['2341198', 'Joined']
# ['2341226', 'Joined']
# ['2341246', 'Not Joined']
# ['2341250', 'Joined']
# ['2341260', 'Joined']
# ['2341276', 'Not Joined']
# ['2341282', 'Joined']
# ['2341304', 'Joined']
# ['2341321', 'Joined']
# ['2341328', 'Not Joined']
# ['2341343', 'Joined']
# ['2341375', 'Not Joined']
# ['2341377', 'Joined']
# ['2341380', 'Not Joined']
# ['2341385', 'Joined']
# ['2341463', 'Joined']
# ['2341532', 'Joined']
# ['2341540', 'Joined']
# ['2341573', 'Joined']
# ['2341594', 'Joined']
# ['2341609', 'Joined']
# ['2341882', 'Joined']
# ['2344320', 'Joined']
# ['2344393', 'Joined']
# ['2344417', 'Joined']
# ['2344479', 'Joined']
# ['2344493', 'Joined']
# ['2344496', 'Joined']
# ['2344500', 'Not Joined']
# ['2344524', 'Not Joined']
# ['2344526', 'Joined']
# ['2344555', 'Joined']
# ['2344561', 'Joined']
# ['2344564', 'Joined']
# ['2344571', 'Not Joined']
# ['2344591', 'Not Joined']
# ['2344626', 'Joined']
# ['2344637', 'Not Joined']
# ['2344675', 'Joined']
# ['2344696', 'Joined']
# ['2344720', 'Joined']
# ['2344721', 'Joined']
# ['2344760', 'Not Joined']
# ['2344790', 'Joined']
# ['2344801', 'Joined']
# ['2344809', 'Joined']
# ['2344843', 'Not Joined']
# ['2344866', 'Joined']
# ['2344890', 'Joined']
# ['2344948', 'Joined']
# ['2344972', 'Not Joined']
# ['2345008', 'Not Joined']
# ['2345026', 'Not Joined']
# ['2345033', 'Joined']
# ['2345141', 'Joined']
# ['2345154', 'Joined']
# ['2345184', 'Joined']
# ['2345246', 'Joined']
# ['2345361', 'Joined']
# ['2347639', 'Joined']
# ['2347665', 'Joined']
# ['2347682', 'Not Joined']
# ['2347707', 'Joined']
# ['2347709', 'Joined']
# ['2347714', 'Joined']
# ['2347794', 'Joined']
# ['2347817', 'Not Joined']
# ['2347820', 'Joined']
# ['2347823', 'Joined']
# ['2347830', 'Not Joined']
# ['2347861', 'Joined']
# ['2347883', 'Joined']
# ['2347905', 'Joined']
# ['2347925', 'Not Joined']
# ['2347926', 'Joined']
# ['2347958', 'Not Joined']
# ['2347971', 'Joined']
# ['2347978', 'Joined']
# ['2347983', 'Joined']
# ['2347985', 'Joined']
# ['2348009', 'Joined']
# ['2348023', 'Not Joined']
# ['2348036', 'Not Joined']
# ['2348060', 'Joined']
# ['2348066', 'Joined']
# ['2348070', 'Not Joined']
# ['2348085', 'Joined']
# ['2348090', 'Joined']
# ['2348093', 'Joined']
# ['2348102', 'Joined']
# ['2348103', 'Joined']
# ['2348104', 'Joined']
# ['2348139', 'Joined']
# ['2348170', 'Joined']
# ['2348181', 'Joined']
# ['2348198', 'Joined']
# ['2348209', 'Not Joined']
# ['2348305', 'Joined']
# ['2348410', 'Joined']
# ['2348443', 'Joined']
# ['2348599', 'Joined']
# ['2349422', 'Joined']
# ['2349443', 'Joined']
# ['2349485', 'Joined']
# ['2350880', 'Not Joined']
# ['2351269', 'Joined']
# ['2351414', 'Not Joined']
# ['2351522', 'Joined']
# ['2351527', 'Not Joined']
# ['2351533', 'Joined']
# ['2351549', 'Joined']
# ['2351587', 'Not Joined']
# ['2351651', 'Not Joined']
# ['2351713', 'Joined']
# ['2351722', 'Joined']
# ['2351755', 'Joined']
# ['2351781', 'Not Joined']
# ['2351783', 'Joined']
# ['2351805', 'Joined']
# ['2351823', 'Joined']
# ['2351837', 'Not Joined']
# ['2351842', 'Joined']
# ['2351858', 'Joined']
# ['2351875', 'Not Joined']
# ['2351880', 'Joined']
# ['2351887', 'Joined']
# ['2351892', 'Joined']
# ['2351895', 'Joined']
# ['2351897', 'Joined']
# ['2351902', 'Joined']
# ['2351912', 'Not Joined']
# ['2351922', 'Joined']
# ['2351930', 'Joined']
# ['2351957', 'Joined']
# ['2351967', 'Joined']
# ['2351969', 'Joined']
# ['2351970', 'Joined']
# ['2351976', 'Joined']
# ['2351989', 'Not Joined']
# ['2352009', 'Joined']
# ['2352030', 'Joined']
# ['2352035', 'Joined']
# ['2352049', 'Joined']
# ['2352074', 'Joined']
# ['2352077', 'Joined']
# ['2352094', 'Joined']
# ['2352101', 'Joined']
# ['2352117', 'Joined']
# ['2352137', 'Joined']
# ['2352147', 'Joined']
# ['2352159', 'Joined']
# ['2352168', 'Joined']
# ['2352172', 'Joined']
# ['2352175', 'Joined']
# ['2352203', 'Joined']
# ['2352238', 'Joined']
# ['2352240', 'Joined']
# ['2352241', 'Joined']
# ['2352243', 'Joined']
# ['2352305', 'Not Joined']
# ['2352320', 'Joined']
# ['2353365', 'Joined']
# ['2353371', 'Joined']
# ['2354228', 'Not Joined']
# ['2354269', 'Not Joined']
# ['2354306', 'Not Joined']
# ['2354325', 'Joined']
# ['2354384', 'Joined']
# ['2354400', 'Joined']
# ['2354413', 'Joined']
# ['2354515', 'Joined']
# ['2354793', 'Joined']
# ['2355364', 'Joined']
# ['2355391', 'Joined']
# ['2355420', 'Joined']
# ['2355458', 'Not Joined']
# ['2355463', 'Joined']
# ['2355503', 'Joined']
# ['2355514', 'Joined']
# ['2355527', 'Joined']
# ['2355539', 'Joined']
# ['2355568', 'Joined']
# ['2355854', 'Joined']
# ['2356640', 'Joined']
# ['2356683', 'Joined']
# ['2356687', 'Joined']
# ['2356692', 'Joined']
# ['2356703', 'Joined']
# ['2356746', 'Joined']
# ['2356796', 'Not Joined']
# ['2356805', 'Not Joined']
# ['2356813', 'Joined']
# ['2356815', 'Joined']
# ['2356822', 'Joined']
# ['2356842', 'Joined']
# ['2356853', 'Joined']
# ['2356867', 'Joined']
# ['2356872', 'Joined']
# ['2356881', 'Joined']
# ['2356894', 'Joined']
# ['2356898', 'Joined']
# ['2356902', 'Joined']
# ['2356911', 'Not Joined']
# ['2356913', 'Joined']
# ['2356922', 'Not Joined']
# ['2356923', 'Not Joined']
# ['2356927', 'Joined']
# ['2356936', 'Not Joined']
# ['2356944', 'Not Joined']
# ['2356974', 'Joined']
# ['2356982', 'Joined']
# ['2356985', 'Joined']
# ['2356992', 'Not Joined']
# ['2357003', 'Joined']
# ['2357013', 'Joined']
# ['2357038', 'Joined']
# ['2357044', 'Joined']
# ['2357062', 'Joined']
# ['2357068', 'Not Joined']
# ['2357079', 'Joined']
# ['2357087', 'Joined']
# ['2357091', 'Joined']
# ['2357093', 'Not Joined']
# ['2357094', 'Joined']
# ['2357103', 'Joined']
# ['2357113', 'Joined']
# ['2357114', 'Not Joined']
# ['2357125', 'Joined']
# ['2357140', 'Joined']
# ['2357147', 'Joined']
# ['2357166', 'Joined']
# ['2357172', 'Joined']
# ['2357175', 'Joined']
# ['2357182', 'Joined']
# ['2357194', 'Not Joined']
# ['2357218', 'Not Joined']
# ['2357258', 'Joined']
# ['2357261', 'Joined']
# ['2357271', 'Joined']
# ['2357274', 'Joined']
# ['2357288', 'Joined']
# ['2357292', 'Joined']
# ['2357311', 'Joined']
# ['2357342', 'Joined']
# ['2357371', 'Not Joined']
# ['2357383', 'Not Joined']
# ['2357384', 'Not Joined']
# ['2357385', 'Not Joined']
# ['2357386', 'Joined']
# ['2357387', 'Joined']
# ['2357421', 'Joined']
# ['2357422', 'Joined']
# ['2357423', 'Joined']
# ['2357424', 'Not Joined']
# ['2357425', 'Joined']
# ['2357426', 'Joined']
# ['2357428', 'Not Joined']
# ['2357429', 'Not Joined']
# ['2357430', 'Not Joined']
# ['2357431', 'Joined']
# ['2357432', 'Not Joined']
# ['2357433', 'Not Joined']
# ['2357434', 'Joined']
# ['2357435', 'Joined']
# ['2357436', 'Joined']
# ['2357437', 'Not Joined']
# ['2357438', 'Not Joined']
# ['2357439', 'Joined']
# ['2357440', 'Not Joined']
# ['2357441', 'Joined']
# ['2357442', 'Not Joined']
# ['2357443', 'Not Joined']
# ['2357444', 'Joined']
# ['2357445', 'Joined']
# ['2357496', 'Joined']
# ['2357644', 'Joined']
# ['2357877', 'Joined']
# ['2357979', 'Joined']
# ['2358051', 'Joined']
# ['2358831', 'Joined']
# ['2359946', 'Joined']
# ['2360011', 'Joined']
# ['2360395', 'Joined']
# ['2360508', 'Joined']
# ['2360542', 'Not Joined']
# ['2360606', 'Joined']
# ['2360630', 'Joined']
# ['2360664', 'Joined']
# ['2360696', 'Joined']
# ['2360750', 'Joined']
# ['2360804', 'Joined']
# ['2360808', 'Not Joined']
# ['2360834', 'Not Joined']
# ['2360841', 'Joined']
# ['2360844', 'Not Joined']
# ['2360861', 'Joined']
# ['2360872', 'Joined']
# ...
# ['3505717', 'Joined']
# ['3505775', 'Joined']
# ['3505796', 'Joined']
# ['3505802', 'Joined']
# ['3505828', 'Not Joined']
# ['3506012', 'Not Joined']
# ['3506013', 'Joined']
# ['3506052', 'Joined']
# ['3506055', 'Joined']
# ['3506184', 'Joined']
# ['3506208', 'Joined']
# ['3506260', 'Joined']
# ['3506338', 'Joined']
# ['3506342', 'Joined']
# ['3506392', 'Joined']
# ['3506424', 'Not Joined']
# ['3506541', 'Not Joined']
# ['3506565', 'Joined']
# ['3506571', 'Joined']
# ['3506582', 'Joined']
# ['3506608', 'Joined']
# ['3506643', 'Joined']
# ['3506660', 'Joined']
# ['3506678', 'Joined']
# ['3506764', 'Joined']
# ['3507356', 'Joined']
# ['3510881', 'Joined']
# ['3510932', 'Joined']
# ['3511007', 'Not Joined']
# ['3511039', 'Joined']
# ['3511052', 'Joined']
# ['3511165', 'Not Joined']
# ['3511222', 'Joined']
# ['3511274', 'Joined']
# ['3511327', 'Joined']
# ['3511350', 'Joined']
# ['3511385', 'Not Joined']
# ['3511425', 'Joined']
# ['3511455', 'Joined']
# ['3511484', 'Joined']
# ['3511533', 'Joined']
# ['3511549', 'Joined']
# ['3511553', 'Joined']
# ['3511637', 'Joined']
# ['3511777', 'Joined']
# ['3511952', 'Joined']
# ['3511954', 'Joined']
# ['3511972', 'Joined']
# ['3512039', 'Joined']
# ['3512058', 'Not Joined']
# ['3512195', 'Joined']
# ['3512233', 'Joined']
# ['3512476', 'Joined']
# ['3512539', 'Joined']
# ['3512584', 'Joined']
# ['3512613', 'Joined']
# ['3513100', 'Joined']
# ['3516384', 'Joined']
# ['3516640', 'Joined']
# ['3516650', 'Joined']
# ['3516974', 'Joined']
# ['3517096', 'Joined']
# ['3517098', 'Not Joined']
# ['3517103', 'Joined']
# ['3517225', 'Joined']
# ['3517315', 'Joined']
# ['3517448', 'Joined']
# ['3517486', 'Joined']
# ['3517522', 'Joined']
# ['3517523', 'Joined']
# ['3518006', 'Not Joined']
# ['3518137', 'Joined']
# ['3523729', 'Joined']
# ['3523929', 'Joined']
# ['3523944', 'Joined']
# ['3524328', 'Joined']
# ['3524366', 'Joined']
# ['3524433', 'Joined']
# ['3524493', 'Joined']
# ['3524500', 'Joined']
# ['3524552', 'Joined']
# ['3524562', 'Joined']
# ['3524610', 'Joined']
# ['3524671', 'Joined']
# ['3524739', 'Joined']
# ['3524745', 'Joined']
# ['3524766', 'Joined']
# ['3524769', 'Joined']
# ['3524771', 'Joined']
# ['3524781', 'Joined']
# ['3524803', 'Joined']
# ['3524834', 'Joined']
# ['3524843', 'Joined']
# ['3524848', 'Joined']
# ['3524979', 'Joined']
# ['3525111', 'Joined']
# ['3525245', 'Joined']
# ['3525306', 'Joined']
# ['3526350', 'Joined']
# ['3528857', 'Joined']
# ['3529261', 'Joined']
# ['3529428', 'Joined']
# ['3529443', 'Joined']
# ['3529480', 'Joined']
# ['3529489', 'Joined']
# ['3529604', 'Joined']
# ['3529704', 'Joined']
# ['3529735', 'Joined']
# ['3529902', 'Joined']
# ['3529927', 'Joined']
# ['3530033', 'Joined']
# ['3530042', 'Joined']
# ['3530240', 'Joined']
# ['3530251', 'Joined']
# ['3530364', 'Joined']
# ['3530434', 'Joined']
# ['3530461', 'Joined']
# ['3530471', 'Joined']
# ['3530476', 'Joined']
# ['3530596', 'Joined']
# ['3530641', 'Joined']
# ['3530648', 'Joined']
# ['3530857', 'Joined']
# ['3533612', 'Joined']
# ['3533962', 'Not Joined']
# ['3533998', 'Joined']
# ['3534047', 'Joined']
# ['3534063', 'Joined']
# ['3534071', 'Joined']
# ['3534154', 'Joined']
# ['3536030', 'Joined']
# ['3537308', 'Joined']
# ['3537336', 'Joined']
# ['3537383', 'Joined']
# ['3537428', 'Joined']
# ['3537464', 'Joined']
# ['3537510', 'Joined']
# ['3537542', 'Not Joined']
# ['3537582', 'Joined']
# ['3537586', 'Joined']
# ['3537648', 'Joined']
# ['3537666', 'Joined']
# ['3537676', 'Not Joined']
# ['3537696', 'Joined']
# ['3537703', 'Joined']
# ['3537723', 'Joined']
# ['3537764', 'Not Joined']
# ['3537790', 'Joined']
# ['3537793', 'Joined']
# ['3537839', 'Joined']
# ['3537842', 'Joined']
# ['3537851', 'Joined']
# ['3537953', 'Joined']
# ['3537988', 'Joined']
# ['3538015', 'Joined']
# ['3538021', 'Joined']
# ['3538171', 'Joined']
# ['3538180', 'Joined']
# ['3538184', 'Joined']
# ['3538193', 'Not Joined']
# ['3538273', 'Joined']
# ['3538356', 'Not Joined']
# ['3538374', 'Joined']
# ['3538567', 'Joined']
# ['3538596', 'Joined']
# ['3538628', 'Joined']
# ['3538635', 'Not Joined']
# ['3538811', 'Joined']
# ['3540194', 'Joined']
# ['3544439', 'Joined']
# ['3544465', 'Joined']
# ['3544483', 'Joined']
# ['3544726', 'Not Joined']
# ['3544822', 'Joined']
# ['3544845', 'Joined']
# ['3544858', 'Joined']
# ['3544919', 'Joined']
# ['3544926', 'Not Joined']
# ['3544963', 'Joined']
# ['3545073', 'Joined']
# ['3545155', 'Joined']
# ['3545160', 'Joined']
# ['3545274', 'Joined']
# ['3545294', 'Joined']
# ['3545376', 'Joined']
# ['3545588', 'Joined']
# ['3545746', 'Joined']
# ['3545999', 'Joined']
# ['3546090', 'Joined']
# ['3547515', 'Joined']
# ['3576106', 'Joined']
# ['3576681', 'Joined']
# ['3576784', 'Joined']
# ['3577070', 'Joined']
# ['3577108', 'Joined']
# ['3577117', 'Joined']
# ['3577122', 'Not Joined']
# ['3577175', 'Joined']
# ['3577229', 'Joined']
# ['3577320', 'Not Joined']
# ['3577361', 'Joined']
# ['3577383', 'Joined']
# ['3577521', 'Joined']
# ['3577568', 'Joined']
# ['3577590', 'Joined']
# ['3577701', 'Joined']
# ['3577724', 'Joined']
# ['3577947', 'Joined']
# ['3577965', 'Joined']
# ['3578191', 'Not Joined']
# ['3578241', 'Joined']
# ['3582300', 'Joined']
# ['3582374', 'Not Joined']
# ['3582561', 'Joined']
# ['3582667', 'Joined']
# ['3582790', 'Joined']
# ['3583012', 'Joined']
# ['3583161', 'Joined']
# ['3583258', 'Joined']
# ['3583384', 'Joined']
# ['3583453', 'Joined']
# ['3587325', 'Joined']
# ['3587458', 'Joined']
# ['3587530', 'Joined']
# ['3587594', 'Joined']
# ['3587779', 'Joined']
# ['3587969', 'Not Joined']
# ['3587975', 'Joined']
# ['3588128', 'Joined']
# ['3588170', 'Joined']
# ['3588319', 'Joined']
# ['3588405', 'Joined']
# ['3588434', 'Joined']
# ['3588489', 'Joined']
# ['3588525', 'Joined']
# ['3588618', 'Joined']
# ['3588635', 'Joined']
# ['3588645', 'Joined']
# ['3588738', 'Joined']
# ['3588799', 'Joined']
# ['3588803', 'Joined']
# ['3588807', 'Joined']
# ['3588811', 'Joined']
# ['3588826', 'Joined']
# ['3588834', 'Joined']
# ['3589150', 'Joined']
# ['3592183', 'Joined']
# ['3594182', 'Joined']
# ['3599361', 'Joined']
# ['3599482', 'Joined']
# ['3599535', 'Joined']
# ['3599548', 'Joined']
# ['3599581', 'Joined']
# ['3599611', 'Joined']
# ['3599637', 'Joined']
# ['3599675', 'Joined']
# ['3599704', 'Joined']
# ['3599714', 'Joined']
# ['3599722', 'Joined']
# ['3599755', 'Joined']
# ['3599763', 'Joined']
# ['3599823', 'Joined']
# ['3599872', 'Joined']
# ['3599934', 'Joined']
# ['3600029', 'Joined']
# ['3600044', 'Joined']
# ['3600157', 'Joined']
# ['3600159', 'Joined']
# ['3600169', 'Joined']
# ['3600182', 'Joined']
# ['3600207', 'Joined']
# ['3600277', 'Joined']
# ['3600360', 'Joined']
# ['3600420', 'Joined']
# ['3600457', 'Joined']
# ['3600517', 'Joined']
# ['3600525', 'Joined']
# ['3600539', 'Not Joined']
# ['3600565', 'Not Joined']
# ['3600591', 'Joined']
# ['3600671', 'Joined']
# ['3600728', 'Joined']
# ['3600813', 'Joined']
# ['3600824', 'Joined']
# ['3600829', 'Joined']
# ['3600833', 'Joined']
# ['3600998', 'Joined']
# ['3601161', 'Joined']
# ['3601205', 'Joined']
# ['3605689', 'Joined']
# ['3605890', 'Joined']
# ['3606202', 'Joined']
# ['3606220', 'Joined']
# ['3606306', 'Joined']
# ['3606318', 'Joined']
# ['3606401', 'Joined']
# ['3606508', 'Joined']
# ['3606574', 'Joined']
# ['3606763', 'Joined']
# ['3606810', 'Joined']
# ['3606853', 'Joined']
# ['3607029', 'Joined']
# ['3607129', 'Joined']
# ['3607147', 'Joined']
# ['3607200', 'Joined']
# ['3607223', 'Joined']
# ['3607225', 'Joined']
# ['3607236', 'Joined']
# ['3607578', 'Joined']
# ['3607598', 'Joined']
# ['3607642', 'Joined']
# ['3607703', 'Joined']
# ['3608107', 'Joined']
# ['3611450', 'Joined']
# ['3611596', 'Joined']
# ['3611691', 'Joined']
# ['3612096', 'Joined']
# ['3612211', 'Joined']
# ['3612285', 'Joined']
# ['3612451', 'Joined']
# ['3612664', 'Joined']
# ['3612737', 'Joined']
# ['3612791', 'Joined']
# ['3612843', 'Joined']
# ['3612858', 'Joined']
# ['3612866', 'Joined']
# ['3612934', 'Joined']
# ['3612936', 'Joined']
# ['3612966', 'Joined']
# ['3613057', 'Not Joined']
# ['3613305', 'Not Joined']
# ['3613962', 'Joined']
# ['3616952', 'Joined']
# ['3617144', 'Joined']
# ['3617382', 'Joined']
# ['3617402', 'Joined']
# ['3617434', 'Joined']
# ['3617566', 'Joined']
# ['3617596', 'Joined']
# ['3617621', 'Not Joined']
# ['3617787', 'Not Joined']
# ['3617812', 'Not Joined']
# ['3617899', 'Joined']
# ['3617940', 'Joined']
# ['3617942', 'Joined']
# ['3617962', 'Joined']
# ['3617970', 'Joined']
# ['3618238', 'Joined']
# ['3618293', 'Joined']
# ['3618342', 'Joined']
# ['3618375', 'Joined']
# ['3618684', 'Joined']
# ['3618701', 'Joined']
# ['3618736', 'Joined']
# ['3618738', 'Joined']
# ['3618759', 'Joined']
# ['3618776', 'Joined']
# ['3618836', 'Joined']
# ['3619017', 'Joined']
# ['3619090', 'Joined']
# ['3621790', 'Joined']
# ['3621817', 'Joined']
# ['3622033', 'Not Joined']
# ['3622047', 'Joined']
# ['3622112', 'Joined']
# ['3622179', 'Joined']
# ['3622218', 'Joined']
# ['3622262', 'Joined']
# ['3622403', 'Joined']
# ['3622428', 'Joined']
# ['3622485', 'Joined']
# ['3622683', 'Joined']
# ['3622688', 'Joined']
# ['3622701', 'Not Joined']
# ['3622753', 'Joined']
# ['3622765', 'Not Joined']
# ['3622788', 'Joined']
# ['3622804', 'Not Joined']
# ['3622835', 'Joined']
# ['3622867', 'Joined']
# ['3622994', 'Joined']
# ['3623106', 'Joined']
# ['3623207', 'Joined']
# ['3623344', 'Joined']
# ['3625589', 'Not Joined']
# ['3625625', 'Not Joined']
# ['3625908', 'Joined']
# ['3626041', 'Joined']
# ['3627401', 'Joined']
# ['3631499', 'Joined']
# ['3631630', 'Joined']
# ['3631825', 'Joined']
# ['3631872', 'Joined']
# ['3631916', 'Joined']
# ['3631957', 'Joined']
# ['3632133', 'Joined']
# ['3632237', 'Joined']
# ['3632418', 'Joined']
# ['3632490', 'Joined']
# ['3632492', 'Not Joined']
# ['3632502', 'Joined']
# ['3632739', 'Joined']
# ['3632819', 'Joined']
# ['3632855', 'Joined']
# ['3632880', 'Joined']
# ['3632913', 'Joined']
# ['3632925', 'Joined']
# ['3632938', 'Joined']
# ['3632941', 'Joined']
# ['3632955', 'Joined']
# ['3633236', 'Joined']
# ['3633730', 'Joined']
# ['3633837', 'Joined']
# ['3636221', 'Joined']
# ['3636560', 'Joined']
# ['3636801', 'Joined']
# ['3636841', 'Joined']
# ['3636853', 'Joined']
# ['3637036', 'Joined']
# ['3637313', 'Joined']
# ['3637334', 'Joined']
# ['3637393', 'Joined']
# ['3637396', 'Not Joined']
# ['3637428', 'Joined']
# ['3637501', 'Joined']
# ['3637518', 'Joined']
# ['3637541', 'Joined']
# ['3637562', 'Joined']
# ['3637568', 'Joined']
# ['3637650', 'Joined']
# ['3637706', 'Not Joined']
# ['3637724', 'Joined']
# ['3637768', 'Joined']
# ['3637797', 'Joined']
# ['3637821', 'Joined']
# ['3637838', 'Joined']
# ['3637883', 'Joined']
# ['3637890', 'Joined']
# ['3637913', 'Joined']
# ['3637988', 'Joined']
# ['3638010', 'Joined']
# ['3638013', 'Joined']
# ['3638059', 'Joined']
# ['3638112', 'Joined']
# ['3638247', 'Joined']
# ['3638262', 'Not Joined']
# ['3638269', 'Joined']
# ['3638301', 'Joined']
# ['3638303', 'Not Joined']
# ['3638312', 'Joined']
# ['3638349', 'Joined']
# ['3638372', 'Joined']
# ['3638439', 'Joined']
# ['3638456', 'Joined']
# ['3638663', 'Joined']
# ['3638834', 'Joined']
# ['3639026', 'Joined']
# ['3639052', 'Joined']
# ['3639633', 'Joined']
# ['3642977', 'Joined']
# ['3643210', 'Joined']
# ['3643316', 'Joined']
# ['3643352', 'Joined']
# ['3643442', 'Joined']
# ['3643447', 'Joined']
# ['3643476', 'Joined']
# ['3643671', 'Not Joined']
# ['3643726', 'Joined']
# ['3644011', 'Joined']
# ['3644063', 'Joined']
# ['3644080', 'Joined']
# ['3644082', 'Joined']
# ['3644500', 'Joined']
# ['3644519', 'Joined']
# ['3644573', 'Joined']
# ['3644605', 'Joined']
# ['3644797', 'Joined']
# ['3644805', 'Joined']
# ['3644843', 'Joined']
# ['3648551', 'Joined']
# ['3648792', 'Joined']
# ['3648919', 'Joined']
# ['3649111', 'Joined']
# ['3649132', 'Joined']
# ['3649157', 'Joined']
# ['3649158', 'Joined']
# ['3649169', 'Joined']
# ['3649286', 'Joined']
# ['3649511', 'Not Joined']
# ['3649551', 'Joined']
# ['3649659', 'Joined']
# ['3649851', 'Joined']
# ['3649871', 'Joined']
# ['3650162', 'Joined']
# ['3650311', 'Joined']
# ['3650440', 'Joined']
# ['3650446', 'Joined']
# ['3654658', 'Joined']
# ['3654707', 'Joined']
# ['3654943', 'Joined']
# ['3655198', 'Joined']
# ['3655228', 'Joined']
# ['3655297', 'Joined']
# ['3656197', 'Joined']
# ['3656253', 'Joined']
# ['3658961', 'Joined']
# ['3659381', 'Joined']
# ['3661318', 'Joined']
# ['3661529', 'Joined']
# ['3663237', 'Joined']
# ['3663759', 'Joined']
# ['3663798', 'Joined']
# ['3663824', 'Joined']
# ['3663949', 'Joined']
# ['3664089', 'Joined']
# ['3664136', 'Joined']
# ['3664153', 'Joined']
# ['3664187', 'Joined']
# ['3664279', 'Not Joined']
# ['3664439', 'Joined']
# ['3664633', 'Joined']
# ['3664736', 'Joined']
# ['3664798', 'Joined']
# ['3664910', 'Joined']
# ['3665333', 'Joined']
# ['3671407', 'Joined']
# ['3671470', 'Joined']
# ['3671696', 'Joined']
# ['3671764', 'Joined']
# ['3671979', 'Joined']
# ['3672027', 'Joined']
# ['3672074', 'Joined']
# ['3672247', 'Joined']
# ['3672274', 'Joined']
# ['3672334', 'Joined']
# ['3672372', 'Joined']
# ['3672412', 'Joined']
# ['3672499', 'Joined']
# ['3672581', 'Joined']
# ['3672918', 'Joined']
# ['3673279', 'Joined']
# ['3680621', 'Joined']
# ['3680640', 'Joined']
# ['3680788', 'Joined']
# ['3680871', 'Joined']
# ['3680937', 'Joined']
# ['3681080', 'Joined']
# ['3681231', 'Joined']
# ['3681247', 'Joined']
# ['3681365', 'Joined']
# ['3681447', 'Joined']
# ['3681972', 'Not Joined']
# ['3681999', 'Joined']
# ['3682006', 'Joined']
# ['3682060', 'Not Joined']
# ['3682063', 'Joined']
# ['3682070', 'Joined']
# ['3682080', 'Joined']
# ['3682340', 'Joined']
# ['3682413', 'Joined']
# ['3685310', 'Joined']
# ['3685341', 'Joined']
# ['3685366', 'Joined']
# ['3685372', 'Joined']
# ['3685413', 'Joined']
# ['3685447', 'Joined']
# ['3685982', 'Joined']
# ['3686026', 'Joined']
# ['3686078', 'Joined']
# ['3686140', 'Joined']
# ['3686153', 'Joined']
# ['3686306', 'Joined']
# ['3686582', 'Joined']
# ['3686619', 'Joined']
# ['3686882', 'Joined']
# ['3687033', 'Joined']
# ['3687051', 'Joined']
# ['3687057', 'Joined']
# ['3687058', 'Joined']
# ['3687178', 'Joined']
# ['3691123', 'Joined']
# ['3691217', 'Joined']
# ['3691231', 'Joined']
# ['3691298', 'Joined']
# ['3691623', 'Joined']
# ['3691790', 'Joined']
# ['3691794', 'Joined']
# ['3692284', 'Joined']
# ['3692641', 'Joined']
# ['3699004', 'Joined']
# ['3699257', 'Joined']
# ['3699326', 'Joined']
# ['3699368', 'Joined']
# ['3699960', 'Joined']
# ['3699965', 'Joined']
# ['3700170', 'Joined']
# ['3700174', 'Joined']
# ['3700231', 'Joined']
# ['3700234', 'Joined']
# ['3700298', 'Joined']
# ['3700315', 'Not Joined']
# ['3700319', 'Joined']
# ['3700330', 'Joined']
# ['3700340', 'Joined']
# ['3700434', 'Joined']
# ['3700536', 'Joined']
# ['3700662', 'Joined']
# ['3706704', 'Joined']
# ['3706995', 'Joined']
# ['3707015', 'Joined']
# ['3707040', 'Joined']
# ['3707510', 'Joined']
# ['3707763', 'Joined']
# ['3710680', 'Joined']
# ['3714121', 'Joined']
# ['3714354', 'Joined']
# ['3714640', 'Joined']
# ['3714991', 'Joined']
# ['3715038', 'Joined']
# ['3715080', 'Joined']
# ['3715223', 'Joined']
# ['3715259', 'Joined']
# ['3720977', 'Joined']
# ['3720998', 'Joined']
# ['3721007', 'Joined']
# ['3721105', 'Joined']
# ['3721335', 'Joined']
# ['3721720', 'Joined']
# ['3721993', 'Joined']
# ['3722046', 'Joined']
# ['3722173', 'Joined']
# ['3722278', 'Joined']
# ['3722382', 'Joined']
# ['3722422', 'Joined']
# ['3726559', 'Joined']
# ['3727613', 'Joined']
# ['3728012', 'Joined']
# ['3728327', 'Joined']
# ['3728462', 'Joined']
# ['3728613', 'Joined']
# ['3728943', 'Joined']
# ['3732796', 'Joined']
# ['3732973', 'Joined']
# ['3733017', 'Joined']
# ['3733027', 'Not Joined']
# ['3737201', 'Joined']
# ['3737337', 'Joined']
# ['3737574', 'Joined']
# ['3737741', 'Joined']
# ['3737746', 'Joined']
# ['3737752', 'Joined']
# ['3737804', 'Joined']
# ['3738246', 'Joined']
# ['3738377', 'Joined']
# ['3738652', 'Joined']
# ['3738944', 'Joined']
# ['3739022', 'Joined']
# ['3744460', 'Joined']
# ['3745231', 'Joined']
# ['3746127', 'Joined']
# ['3746228', 'Joined']
# ['3746555', 'Joined']
# ['3746653', 'Joined']
# ['3751754', 'Joined']
# ['3752710', 'Joined']
# ['3757762', 'Joined']
# ['3758488', 'Joined']
# ['3758618', 'Joined']
# ['3758699', 'Joined']
# ['3758707', 'Joined']
# ['3758805', 'Joined']
# ['3758899', 'Joined']
# ['3759268', 'Joined']
# ['3759365', 'Joined']
# ['3759492', 'Joined']
# ['3759772', 'Joined']
# ['3763262', 'Joined']
# ['3763431', 'Joined']
# ['3764337', 'Joined']
# ['3764613', 'Joined']
# ['3766450', 'Joined']
# ['3772066', 'Joined']
# ['3772180', 'Joined']
# ['3772216', 'Joined']
# ['3772228', 'Joined']
# ['3773789', 'Joined']
# ['3778365', 'Joined']
# ['3779918', 'Joined']
# ['3781517', 'Joined']
# ['3785141', 'Joined']
# ['3785313', 'Joined']
# ['3785527', 'Joined']
# ['3785691', 'Joined']
# ['3786087', 'Joined']
# ['3786517', 'Joined']
# ['3786639', 'Joined']
# ['3791441', 'Joined']
# ['3796690', 'Joined']
# ['3796931', 'Joined']
# ['3796981', 'Joined']
# ['3797489', 'Joined']
# ['3798484', 'Not Joined']
# ['3802744', 'Joined']
# ['3807061', 'Joined']
# ['3807072', 'Joined']
# ['3807143', 'Joined']
# ['3807302', 'Joined']
# ['3808142', 'Joined']
# ['3815009', 'Joined']
# ['3815263', 'Joined']
# ['3821185', 'Joined']
# ['3821706', 'Joined']
# ['3822084', 'Not Joined']
# ['3822427', 'Joined']
# ['3828206', 'Joined']
# ['3834159', 'Joined']
# ['3835433', 'Joined']
# ['3836076', 'Joined']

# %%
# Reading Hr Hiring details
with open('HR_Hiring_details_transaction.csv', 'r') as file_to_read:
        data = csv.reader(file_to_read)
        for i in data:
            print(i)
# Out:
# ['Sno', 'Candidate_Ref', 'DOJ_Extended', 'Duration_to_accept_offer', 'Notice_Period', 'Offered_Band', 'ected_in_CTCPercent_hike_exp', 'Percent_hike_offered_in_CTC', 'Percent_difference_CTC', 'Joining_Bonus', 'Candidate_relocate_actual', 'Gender', 'Candidate_Source', 'Rex_in_Yrs', 'Location_ID', 'Postal_Code', 'Age', 'LOB_Id', 'Domicile_Id']
# ['1', '2110407', 'Yes', '14', '30', 'E2', '-20.79', '13.16', '42.86', 'No', 'No', 'Female', 'Agency', '7', 'L001', '201301', '34', '1', 'D6']
# ['2', '2112635', 'No', '18', '30', 'E2', '50', '320', '180', 'No', 'No', 'Male', 'Employee Referral', '8', 'L002', '600020', '34', '2', 'D9']
# ['3', '2112838', 'No', '3', '45', 'E2', '42.84', '42.84', '0', 'No', 'No', 'Male', 'Agency', '4', 'L001', '201301', '27', '2', 'D10']
# ['4', '2115021', 'No', '26', '30', 'E2', '42.84', '42.84', '0', 'No', 'No', 'Male', 'Employee Referral', '4', 'L001', '201301', '34', '2', 'D3']
# ['5', '2115125', 'Yes', '1', '120', 'E2', '42.59', '42.59', '0', 'No', 'Yes', 'Male', 'Employee Referral', '6', 'L001', '201301', '34', '2', 'D21']
# ['6', '2117167', 'Yes', '17', '30', 'E1', '42.83', '42.83', '0', 'No', 'No', 'Male', 'Employee Referral', '2', 'L001', '201301', '34', '2', 'D24']
# ['7', '2119124', 'Yes', '37', '30', 'E2', '31.58', '31.58', '0', 'No', 'No', 'Male', 'Employee Referral', '7', 'L001', '201301', '32', '2', 'D23']
# ['9', '2127572', 'Yes', '16', '0', 'E1', '-20', '-20', '0', 'No', 'No', 'Female', 'Direct', '8', 'L001', '201301', '34', '3', 'D6']
# ['11', '2138169', 'No', '1', '30', 'E1', '-22.22', '-22.22', '0', 'No', 'No', 'Female', 'Employee Referral', '3', 'L003', '122107', '26', '4', 'D5']
# ['12', '2143362', 'No', '6', '30', 'E1', '240', '220', '-5.88', 'No', 'No', 'Male', 'Employee Referral', '3', 'L002', '600020', '34', '5', 'D23']
# ['13', '2151180', 'No', '120', '30', 'E2', '5.26', '-60.53', '-62.5', 'No', 'No', 'Male', 'Employee Referral', '3', 'L001', '201301', '34', '2', 'D6']
# ['14', '2154264', 'No', '3', '0', 'E2', '28.21', '37.18', '7', 'No', 'No', 'Male', 'Employee Referral', '7', 'L002', '600020', '34', '2', 'D3']
# ['15', '2156236', 'Yes', '14', '30', 'E2', '50', '287.5', '158.33', 'No', 'No', 'Male', 'Agency', '7', 'L001', '201301', '29', '2', 'D13']
# ['16', '2158703', 'No', '44', '75', 'E2', '45.45', '60', '10', 'No', 'No', 'Male', 'Direct', '8', 'L001', '201301', '34', '2', 'D13']
# ['17', '2161257', 'No', '7', '30', 'E3', '53.85', '50', '-2.5', 'No', 'No', 'Male', 'Employee Referral', '5', 'L001', '201301', '34', '2', 'D9']
# ['18', '2162487', 'No', '1', '30', 'E3', '-27.31', '-27.31', '0', 'No', 'No', 'Male', 'Direct', '18', 'L004', '560034', '34', '6', 'D13']
# ['19', '2166041', 'Yes', '98', '30', 'E2', '50', '165.36', '76.91', 'No', 'No', 'Male', 'Agency', '8', 'L001', '201301', '36', '2', 'D4']
# ['20', '2172982', 'No', '1', '0', 'E2', '30', '30', '0', 'No', 'No', 'Male', 'Direct', '6', 'L001', '201301', '34', '2', 'D13']
# ['21', '2173730', 'No', '1', '30', 'E1', '-13.42', '42.86', '65', 'No', 'No', 'Male', 'Direct', '1', 'L003', '122107', '34', '2', 'D7']
# ['22', '2175237', 'No', '7', '30', 'E1', '221.43', '164.29', '-17.78', 'No', 'No', 'Male', 'Direct', '2', 'L001', '201301', '34', '1', 'D21']
# ['23', '2175323', 'No', '1', '0', 'E3', '42.78', '42.78', '0', 'No', 'Yes', 'Male', 'Employee Referral', '8', 'L002', '600020', '29', '2', 'D6']
# ['24', '2184108', 'No', '0', '30', 'E1', '37.5', '37.5', '0', 'No', 'No', 'Female', 'Employee Referral', '3', 'L002', '600020', '30', '1', 'D19']
# ['25', '2188014', 'No', '1', '0', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Direct', '5', 'L001', '201301', '30', '2', 'D11']
# ['26', '2191237', 'Yes', '83', '60', 'E2', '25', '25', '0', 'No', 'No', 'Male', 'Direct', '5', 'L001', '201301', '30', '7', 'D24']
# ['27', '2194323', 'No', '1', '0', 'E3', '114.82', '42.86', '-33.5', 'No', 'No', 'Male', 'Direct', '6', 'L001', '201301', '31', '2', 'D16']
# ['28', '2205244', 'No', '16', '60', 'E1', '41.18', '0', '-29.17', 'No', 'No', 'Male', 'Direct', '7', 'L001', '201301', '31', '7', 'D5']
# ['29', '2205496', 'Yes', '32', '120', 'E3', '50.97', '57', '4', 'No', 'No', 'Male', 'Direct', '13', 'L002', '600020', '40', '1', 'D9']
# ['30', '2207823', 'Yes', '19', '30', '', '42.85', '42.85', '0', 'No', 'No', 'Male', 'Direct', '7', 'L001', '201301', '28', '2', 'D13']
# ['31', '2211699', 'Yes', '0', '0', 'E2', '23.08', '15.38', '-6.25', 'No', 'No', 'Male', 'Employee Referral', '6', 'L002', '600020', '34', '4', 'D5']
# ['32', '2214217', 'No', '4', '30', 'E2', '-2.17', '-2.17', '0', 'No', 'No', 'Female', 'Employee Referral', '5', 'L002', '600020', '33', '1', 'D24']
# ['33', '2214446', 'No', '38', '45', 'E2', '42.11', '42.11', '0', 'No', 'No', 'Male', 'Direct', '13', 'L002', '600020', '25', '4', 'D21']
# ['37', '2221643', 'No', '0', '30', 'E3', '-14.91', '-14.91', '0', 'No', 'Yes', 'Male', 'Employee Referral', '15', 'L001', '201301', '44', '2', 'D16']
# ['38', '2221707', 'Yes', '18', '90', 'E2', '33.33', '211.11', '133.33', 'No', 'No', 'Male', 'Agency', '6', 'L005', '500004', '23', '1', 'D18']
# ['39', '2222480', 'No', '24', '30', 'E2', '20.48', '23.95', '2.88', 'No', 'No', 'Male', 'Direct', '6', 'L002', '600020', '29', '2', 'D11']
# ['40', '2222936', 'Yes', '10', '60', 'E3', '25', '29.17', '3.33', 'No', 'No', 'Male', 'Employee Referral', '6', 'L001', '201301', '32', '2', 'D19']
# ['41', '2223040', 'Yes', '53', '60', 'E2', '34.64', '28.52', '-4.55', 'No', 'No', 'Male', 'Direct', '6', 'L004', '560034', '30', '7', 'D4']
# ['43', '2224425', 'No', '0', '0', 'E3', '89.58', '89.58', '0', 'No', 'No', 'Male', 'Direct', '20', 'L004', '560034', '44', '1', 'D3']
# ['44', '2224426', 'Yes', '5', '0', 'E2', '28.57', '28.57', '0', 'Yes', 'Yes', 'Male', 'Employee Referral', '6', 'L004', '560034', '33', '7', 'D15']
# ['45', '2225685', 'No', '0', '0', 'E3', '7.69', '-5.79', '-12.52', 'No', 'No', 'Male', 'Employee Referral', '13', 'L001', '201301', '41', '2', 'D5']
# ['46', '2226215', 'No', '4', '30', 'E1', '-14.58', '-14.58', '0', 'No', 'No', 'Male', 'Direct', '2', 'L001', '201301', '28', '2', 'D14']
# ['47', '2227339', 'Yes', '46', '30', 'E3', '22.22', '260', '194.55', 'No', 'No', 'Male', 'Employee Referral', '13', 'L002', '600020', '36', '1', 'D7']
# ['48', '2227431', 'Yes', '2', '75', 'E3', '42.85', '42.85', '0', 'No', 'Yes', 'Male', 'Employee Referral', '8', 'L001', '201301', '30', '2', 'D19']
# ['49', '2233506', 'No', '1', '90', 'E2', '42.85', '42.85', '0', 'No', 'No', 'Male', 'Employee Referral', '6', 'L001', '201301', '31', '2', 'D20']
# ['51', '2237763', 'Yes', '31', '90', 'E2', '7.96', '-55.75', '-59.02', 'No', 'No', 'Male', 'Employee Referral', '6', 'L001', '201301', '32', '2', 'D7']
# ['52', '2237899', 'Yes', '4', '0', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Female', 'Employee Referral', '10', 'L001', '201301', '34', '2', 'D19']
# ['53', '2238751', 'Yes', '54', '60', 'E3', '35', '31', '-2.96', 'No', 'No', 'Male', 'Employee Referral', '9', 'L001', '201301', '34', '2', 'D6']
# ['54', '2238809', 'No', '33', '75', 'E3', '31.82', '31.82', '0', 'No', 'No', 'Male', 'Employee Referral', '7', 'L001', '201301', '20', '2', 'D23']
# ['56', '2245529', 'Yes', '1', '30', 'E2', '62.5', '12.5', '-30.77', 'No', 'No', 'Female', 'Employee Referral', '3', 'L001', '201301', '30', '2', 'D9']
# ['58', '2281509', 'No', '1', '30', 'E2', '42.86', '42.86', '0', 'Yes', 'No', 'Male', 'Employee Referral', '4', 'L003', '122107', '28', '2', 'D18']
# ['61', '2282688', 'No', '4', '30', 'E1', '233.33', '150', '-25', 'No', 'No', 'Female', 'Direct', '1', 'L002', '600020', '25', '1', 'D10']
# ['62', '2282703', 'No', '4', '30', 'E1', '233.33', '150', '-25', 'No', 'No', 'Female', 'Direct', '1', 'L002', '600020', '25', '1', 'D3']
# ['64', '2283257', 'No', '2', '0', 'E2', '49.89', '49.89', '0', 'No', 'Yes', 'Male', 'Direct', '8', 'L002', '600020', '34', '2', 'D2']
# ['65', '2286200', 'Yes', '5', '120', 'E1', '42.86', '0', '-30', 'No', 'No', 'Male', 'Direct', '5', 'L001', '201301', '28', '7', 'D11']
# ['66', '2286297', 'Yes', '105', '120', 'E1', '-16.67', '-16.67', '0', 'No', 'No', 'Female', 'Direct', '3', 'L006', '700027', '34', '7', 'D18']
# ['67', '2286317', 'No', '1', '60', 'E3', '25', '20.83', '-3.33', 'No', 'No', 'Male', 'Employee Referral', '6', 'L001', '201301', '31', '2', 'D18']
# ['68', '2286381', 'Yes', '14', '30', '', '-12.5', '-12.5', '0', 'No', 'No', 'Male', 'Direct', '3', 'L006', '700027', '31', '7', 'D4']
# ['69', '2286467', 'No', '0', '90', 'E1', '33.5', '28.64', '-3.64', 'No', 'No', 'Male', 'Employee Referral', '3', 'L001', '201301', '26', '7', 'D11']
# ['70', '2286651', 'Yes', '17', '30', 'E2', '40', '15', '-17.86', 'No', 'No', 'Female', 'Direct', '9', 'L003', '122107', '37', '5', 'D20']
# ['71', '2287263', 'Yes', '69', '75', 'E2', '57.14', '46.43', '-6.82', 'No', 'No', 'Male', 'Employee Referral', '6', 'L004', '560034', '29', '6', 'D2']
# ['72', '2287314', 'Yes', '68', '60', 'E1', '47.73', '42.05', '-3.85', 'No', 'No', 'Male', 'Direct', '3', 'L002', '600020', '26', '1', 'D12']
# ['73', '2301543', 'No', '1', '60', 'E2', '37.5', '-12.5', '-36.36', 'No', 'No', 'Male', 'Direct', '2', 'L001', '201301', '33', '2', 'D10']
# ['74', '2302202', 'Yes', '7', '30', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Direct', '6', 'L005', '500004', '32', '2', 'D23']
# ['76', '2322849', 'Yes', '19', '60', 'E2', '50', '30.5', '-13', 'No', 'No', 'Male', 'Agency', '10', 'L002', '600020', '33', '1', 'D3']
# ['77', '2322986', 'Yes', '84', '60', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Agency', '9', 'L002', '600020', '33', '1', 'D13']
# ['78', '2328123', 'No', '28', '30', 'E1', '233.33', '233.33', '0', 'No', 'No', 'Male', 'Direct', '3', 'L004', '560034', '30', '6', 'D6']
# ['80', '2328443', 'No', '0', '30', 'E3', '246.94', '206.12', '-11.76', 'No', 'No', 'Male', 'Direct', '10', 'L002', '600020', '33', '1', 'D14']
# ['84', '2344484', 'No', '126', '30', 'E1', '67.6', '74.58', '4.17', 'No', 'No', 'Male', 'Agency', '5', 'L002', '600020', '27', '1', 'D19']
# ['86', '2347819', 'No', '2', '30', 'E1', '14.75', '-50.82', '-57.14', 'No', 'No', 'Female', 'Agency', '5', 'L002', '600020', '29', '1', 'D16']
# ['87', '2348220', 'No', '4', '30', 'E1', '185.71', '90.48', '-33.33', 'No', 'No', 'Female', 'Direct', '3', 'L002', '600020', '30', '1', 'D20']
# ['88', '2351625', 'Yes', '0', '30', 'E2', '22.73', '15.45', '-5.93', 'No', 'No', 'Male', 'Agency', '8', 'L002', '600020', '37', '8', 'D4']
# ['89', '2351866', 'Yes', '10', '30', 'E1', '-15.32', '-15.32', '0', 'No', 'No', 'Male', 'Employee Referral', '5', 'L004', '560034', '29', '6', 'D10']
# ['90', '2352045', 'No', '0', '30', 'E1', '-10.89', '9.14', '22.47', 'No', 'No', 'Male', 'Direct', '1', 'L001', '201301', '25', '2', 'D8']
# ['92', '2352237', 'No', '0', '0', 'E1', '11.11', '-16.67', '-25', 'No', 'No', 'Female', 'Direct', '1', 'L001', '201301', '24', '2', 'D5']
# ['94', '2354362', 'Yes', '0', '0', 'E1', '11.11', '-16.67', '-25', 'No', 'No', 'Female', 'Direct', '1', 'L001', '201301', '23', '2', 'D16']
# ['96', '2356737', 'No', '16', '30', 'E1', '0', '-30.46', '-30.46', 'No', 'No', 'Male', 'Direct', '1', 'L004', '560034', '24', '1', 'D8']
# ['98', '2361174', 'Yes', '106', '90', 'E2', '38.89', '27.31', '-8.33', 'No', 'No', 'Male', 'Direct', '7', 'L004', '560034', '31', '4', 'D11']
# ['99', '2364321', 'Yes', '90', '45', 'E3', '150', '48.5', '-40.6', 'No', 'No', 'Female', 'Direct', '10', 'L004', '560034', '36', '1', 'D7']
# ['100', '2364483', 'Yes', '14', '30', 'E1', '-13.33', '-13.33', '0', 'No', 'No', 'Male', 'Direct', '2', 'L001', '201301', '29', '2', 'D17']
# ['101', '2364616', 'Yes', '3', '30', 'E2', '49.25', '42.86', '-4.28', 'No', 'No', 'Male', 'Direct', '5', 'L002', '600020', '32', '2', 'D21']
# ['102', '2365129', 'No', '4', '30', '', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Direct', '2', 'L007', '682001', '24', '2', 'D12']
# ['103', '2368400', 'No', '0', '30', 'E1', '-6.25', '-6.25', '0', 'No', 'No', 'Male', 'Direct', '0', 'L002', '600020', '32', '6', 'D5']
# ['104', '2368563', 'No', '6', '30', 'E1', '35.71', '42.86', '5.26', 'No', 'No', 'Female', 'Agency', '3', 'L002', '600020', '28', '1', 'D12']
# ['106', '2372840', 'Yes', '21', '30', 'E1', '-25.52', '-25.52', '0', 'No', 'No', 'Male', 'Direct', '1', 'L002', '600020', '23', '2', 'D8']
# ['108', '2377978', 'No', '36', '30', 'E1', '77.78', '94.44', '9.38', 'No', 'No', 'Male', 'Direct', '1', 'L004', '560034', '24', '1', 'D19']
# ['109', '2377993', 'No', '17', '30', 'E1', '150', '250', '40', 'No', 'No', 'Female', 'Direct', '1', 'L004', '560034', '27', '1', 'D12']
# ['110', '2378003', 'No', '0', '30', 'E1', '25', '62.5', '30', 'No', 'No', 'Male', 'Direct', '2', 'L004', '560034', '27', '1', 'D12']
# ['112', '2378097', 'Yes', '34', '30', 'E1', '75', '75', '0', 'No', 'No', 'Male', 'Direct', '2', 'L002', '600020', '25', '1', 'D24']
# ['113', '2378111', 'No', '34', '30', 'E1', '0', '32.81', '32.81', 'No', 'No', 'Male', 'Direct', '3', 'L004', '560034', '29', '1', 'D22']
# ['114', '2378829', 'No', '0', '30', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Direct', '3', 'L004', '560034', '29', '2', 'D12']
# ['115', '2382818', 'Yes', '20', '30', 'E2', '25.45', '12.01', '-10.71', 'No', 'No', 'Male', 'Agency', '7', 'L002', '600020', '41', '8', 'D14']
# ['116', '2383202', 'No', '13', '30', 'E1', '50', '50', '0', 'No', 'No', 'Female', 'Agency', '3', 'L005', '500004', '32', '1', 'D17']
# ['117', '2398717', 'No', '2', '30', 'E2', '79.57', '60.99', '-10.34', 'No', 'No', 'Male', 'Agency', '7', 'L004', '560034', '33', '1', 'D23']
# ['118', '2400028', 'Yes', '20', '30', 'E2', '157.94', '158.93', '0.38', 'No', 'No', 'Male', 'Agency', '11', 'L002', '600020', '32', '1', 'D18']
# ['119', '2403871', 'No', '1', '30', 'E1', '-45.81', '-45.81', '0', 'No', 'No', 'Male', 'Direct', '1', 'L005', '500004', '26', '2', 'D1']
# ['120', '2407721', 'Yes', '6', '30', 'E1', '12.5', '-53.75', '-58.89', 'No', 'No', 'Male', 'Agency', '1', 'L002', '600020', '27', '1', 'D6']
# ['121', '2416792', 'Yes', '8', '60', 'E2', '33.33', '26.67', '-5', 'No', 'No', 'Male', 'Direct', '7', 'L002', '600020', '29', '1', 'D23']
# ['123', '2417836', 'Yes', '42', '45', 'E2', '7.37', '7.37', '0', 'No', 'No', 'Male', 'Employee Referral', '4', 'L004', '560034', '26', '7', 'D8']
# ['124', '2419759', 'Yes', '12', '60', 'E1', '208.33', '208.33', '0', 'No', 'No', 'Male', 'Direct', '2', 'L002', '600020', '29', '1', 'D4']
# ['125', '2424526', 'Yes', '16', '90', 'E2', '11.11', '-22.22', '-30', 'No', 'No', 'Male', 'Agency', '9', 'L002', '600020', '30', '1', 'D7']
# ['128', '2437820', 'Yes', '14', '60', 'E3', '31.43', '20', '-8.7', 'No', 'No', 'Male', 'Employee Referral', '4', 'L001', '201301', '29', '2', 'D22']
# ['129', '2440646', 'Yes', '103', '45', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Direct', '6', 'L004', '560034', '35', '6', 'D17']
# ['130', '2440672', 'Yes', '69', '45', 'E2', '62.5', '62.5', '0', 'No', 'No', 'Male', 'Direct', '9', 'L005', '500004', '36', '6', 'D19']
# ['131', '2440753', 'Yes', '37', '30', 'E2', '62.5', '37.5', '-15.38', 'No', 'No', 'Male', 'Direct', '6', 'L005', '500004', '29', '6', 'D19']
# ['132', '2441165', 'No', '7', '30', 'E2', '30', '60', '23.08', 'No', 'No', 'Male', 'Agency', '4', 'L002', '600020', '31', '2', 'D14']
# ['133', '2441279', 'No', '2', '60', 'E2', '32.53', '19.28', '-10', 'No', 'No', 'Male', 'Employee Referral', '6', 'L004', '560034', '31', '4', 'D7']
# ['134', '2442101', 'Yes', '38', '45', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Employee Referral', '3', 'L001', '201301', '27', '2', 'D11']
# ['135', '2444384', 'Yes', '43', '60', 'E1', '37.25', '33.33', '-2.86', 'No', 'No', 'Male', 'Direct', '3', 'L002', '600020', '25', '8', 'D16']
# ['136', '2444496', 'Yes', '60', '60', 'E2', '38.89', '11.11', '-20', 'No', 'No', 'Male', 'Direct', '6', 'L004', '560034', '31', '6', 'D24']
# ['137', '2445042', 'No', '3', '30', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Direct', '5', 'L001', '201301', '27', '2', 'D11']
# ['139', '2452418', 'Yes', '32', '30', '', '45.3', '19.66', '-17.65', 'No', 'Yes', 'Male', 'Agency', '7', 'L004', '560034', '30', '6', 'D15']
# ['140', '2452436', 'Yes', '23', '45', 'E2', '29.11', '19.68', '-7.3', 'No', 'No', 'Male', 'Agency', '8', 'L004', '560034', '34', '1', 'D21']
# ['142', '2457480', 'Yes', '67', '60', 'E3', '25', '32.68', '6.14', 'No', 'No', 'Male', 'Agency', '6', 'L001', '201301', '33', '2', 'D10']
# ['143', '2458879', 'No', '5', '30', 'E0', '22.22', '-60', '-67.27', 'No', 'No', 'Female', 'Direct', '1', 'L001', '201301', '27', '1', 'D11']
# ['145', '2461027', 'No', '42', '60', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Employee Referral', '4', 'L001', '201301', '30', '2', 'D7']
# ['146', '2461696', 'No', '8', '30', 'E1', '-30', '0', '42.86', 'No', 'No', 'Male', 'Employee Referral', '7', 'L004', '560034', '30', '1', 'D18']
# ['147', '2464247', 'No', '7', '30', 'E2', '28.3', '28.3', '0', 'No', 'No', 'Male', 'Agency', '7', 'L002', '600020', '29', '2', 'D20']
# ['148', '2464457', 'Yes', '5', '30', 'E1', '208.33', '150', '-18.92', 'No', 'No', 'Male', 'Agency', '3', 'L004', '560034', '28', '1', 'D15']
# ['149', '2464782', 'No', '10', '30', 'E3', '-25', '-20.39', '6.14', 'No', 'No', 'Male', 'Agency', '13', 'L002', '600020', '50', '2', 'D14']
# ['150', '2468663', 'No', '5', '30', 'E1', '51.52', '66.67', '10', 'No', 'No', 'Male', 'Direct', '1', 'L004', '560034', '25', '1', 'D16']
# ['151', '2468764', 'No', '5', '30', 'E1', '51.52', '70.45', '12.5', 'No', 'No', 'Male', 'Direct', '2', 'L004', '560034', '24', '1', 'D21']
# ['152', '2473555', 'No', '12', '30', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Employee Referral', '4', 'L001', '201301', '31', '2', 'D19']
# ['153', '2474614', 'No', '15', '0', 'E3', '-11.97', '-11.97', '0', 'No', 'Yes', 'Male', 'Employee Referral', '11', 'L002', '600020', '35', '1', 'D15']
# ['154', '2474728', 'Yes', '45', '60', 'E2', '25', '18.75', '-5', 'No', 'No', 'Male', 'Direct', '7', 'L004', '560034', '35', '4', 'D7']
# ['155', '2474750', 'No', '10', '30', 'E1', '250', '250', '0', 'No', 'No', 'Male', 'Direct', '1', 'L002', '600020', '23', '1', 'D24']
# ['158', '2478398', 'Yes', '7', '30', 'E2', '323.08', '314.53', '-2.02', 'No', 'No', 'Male', 'Agency', '4', 'L001', '201301', '31', '2', 'D24']
# ['160', '2478695', 'Yes', '7', '30', 'E1', '25', '17.19', '-6.25', 'No', 'No', 'Male', 'Employee Referral', '7', 'L004', '560034', '31', '1', 'D12']
# ['161', '2479005', 'Yes', '36', '30', 'E1', '133.33', '75', '-25', 'No', 'No', 'Female', 'Agency', '3', 'L002', '600020', '27', '1', 'D19']
# ['162', '2480992', 'No', '2', '30', 'E2', '30', '44', '10.77', 'No', 'No', 'Male', 'Direct', '7', 'L001', '201301', '31', '2', 'D8']
# ['163', '2481514', 'No', '1', '0', 'E1', '-14.44', '22.22', '42.86', 'No', 'No', 'Female', 'Employee Referral', '5', 'L002', '600020', '30', '1', 'D5']
# ['164', '2483538', 'Yes', '25', '30', 'E2', '-48.05', '42.86', '175', 'No', 'No', 'Male', 'Direct', '5', 'L001', '201301', '30', '2', 'D9']
# ['165', '2537835', 'No', '6', '30', 'E2', '-40.82', '-15.45', '42.86', 'No', 'No', 'Male', 'Agency', '6', 'L002', '600020', '29', '1', 'D2']
# ['166', '2537925', 'Yes', '47', '60', 'E3', '45.83', '51.04', '3.57', 'No', 'No', 'Male', 'Agency', '10', 'L001', '201301', '34', '2', 'D17']
# ['167', '2537986', 'Yes', '21', '30', 'E3', '25', '31.25', '5', 'No', 'No', 'Female', 'Employee Referral', '16', 'L006', '700027', '40', '2', 'D18']
# ['169', '2544512', 'Yes', '11', '30', 'E2', '30', '80', '38.46', 'No', 'No', 'Male', 'Agency', '4', 'L002', '600020', '33', '2', 'D11']
# ['170', '2556458', 'No', '4', '30', 'E1', '-11.56', '-11.56', '0', 'No', 'No', 'Female', 'Employee Referral', '1', 'L001', '201301', '24', '2', 'D18']
# ['172', '2561022', 'No', '7', '30', 'E1', '242.86', '42.86', '-58.33', 'No', 'No', 'Male', 'Direct', '1', 'L001', '201301', '30', '2', 'D17']
# ['173', '2561128', 'No', '5', '30', 'E1', '42.86', '-7.14', '-35', 'No', 'No', 'Male', 'Direct', '6', 'L003', '122107', '32', '3', 'D23']
# ['175', '2564986', 'No', '4', '30', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Agency', '5', 'L001', '201301', '37', '2', 'D20']
# ['177', '2569520', 'No', '5', '30', '', '-48.25', '-48.25', '0', 'No', 'No', 'Male', 'Employee Referral', '9', 'L002', '600020', '31', '2', 'D20']
# ['178', '2575776', 'No', '11', '30', 'E1', '327.35', '241.88', '-20', 'No', 'No', 'Male', 'Direct', '3', 'L002', '600020', '26', '1', 'D20']
# ['179', '2576352', 'No', '1', '30', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Direct', '8', 'L002', '600020', '31', '2', 'D1']
# ['180', '2586163', 'No', '2', '30', 'E1', '63.2', '70.62', '4.55', 'No', 'No', 'Male', 'Agency', '5', 'L002', '600020', '28', '1', 'D2']
# ['181', '2586868', 'Yes', '48', '30', 'E3', '30', '80', '38.46', 'No', 'No', 'Male', 'Direct', '7', 'L004', '560034', '31', '2', 'D10']
# ['182', '2590178', 'Yes', '74', '90', 'E1', '40.15', '-1.52', '-29.73', 'No', 'Yes', 'Male', 'Direct', '8', 'L004', '560034', '35', '1', 'D4']
# ['183', '2590903', 'Yes', '4', '30', 'E2', '3.34', '3.34', '0', 'No', 'No', 'Female', 'Direct', '6', 'L002', '600020', '31', '8', 'D16']
# ['185', '2591263', 'No', '3', '30', 'E3', '-24.24', '-24.24', '0', 'No', 'No', 'Male', 'Direct', '13', 'L002', '600020', '36', '2', 'D8']
# ['187', '2591495', 'No', '31', '30', 'E1', '-25.71', '42.86', '92.31', 'No', 'Yes', 'Male', 'Employee Referral', '3', 'L002', '600020', '27', '1', 'D14']
# ['188', '2593939', 'No', '15', '45', 'E1', '65.96', '61.49', '-2.69', 'No', 'No', 'Male', 'Direct', '4', 'L002', '600020', '26', '1', 'D6']
# ['189', '2594486', 'Yes', '30', '30', 'E2', '-28.57', '42.86', '100', 'No', 'No', 'Male', 'Direct', '5', 'L002', '600020', '33', '2', 'D7']
# ['190', '2594579', 'No', '1', '30', 'E1', '-14.97', '42.86', '68', 'No', 'No', 'Female', 'Direct', '2', 'L003', '122107', '27', '2', 'D5']
# ['191', '2598011', 'Yes', '8', '30', 'E2', '-24.81', '42.86', '90', 'No', 'No', 'Male', 'Direct', '5', 'L002', '600020', '36', '2', 'D8']
# ['192', '2598184', 'No', '3', '45', 'E1', '79.17', '79.17', '0', 'No', 'No', 'Female', 'Direct', '3', 'L001', '201301', '27', '5', 'D3']
# ['193', '2600880', 'No', '0', '30', 'E3', '80.95', '52.38', '-15.79', 'No', 'No', 'Male', 'Employee Referral', '13', 'L004', '560034', '37', '4', 'D9']
# ['195', '2605197', 'No', '1', '60', 'E1', '40.35', '31.58', '-6.25', 'No', 'No', 'Female', 'Employee Referral', '1', 'L001', '201301', '25', '1', 'D6']
# ['196', '2609241', 'No', '44', '30', 'E2', '69.23', '53.85', '-9.09', 'No', 'No', 'Female', 'Agency', '7', 'L004', '560034', '33', '4', 'D17']
# ['197', '2609287', 'No', '19', '60', 'E3', '-31.82', '-9.09', '33.33', 'No', 'No', 'Male', 'Direct', '10', 'L004', '560034', '33', '1', 'D20']
# ['198', '2613516', 'No', '3', '30', 'E2', '16.13', '-15.81', '-27.5', 'No', 'No', 'Female', 'Employee Referral', '9', 'L004', '560034', '33', '1', 'D1']
# ['199', '2613742', 'No', '40', '30', 'E1', '233.33', '233.33', '0', 'No', 'No', 'Female', 'Agency', '3', 'L004', '560034', '26', '4', 'D23']
# ['200', '2615966', 'No', '11', '30', 'E1', '-29.2', '-29.2', '0', 'No', 'No', 'Female', 'Employee Referral', '3', 'L005', '500004', '26', '5', 'D13']
# ['201', '2618791', 'No', '1', '30', 'E2', '33.33', '20', '-10', 'No', 'No', 'Female', 'Direct', '6', 'L001', '201301', '37', '7', 'D11']
# ['203', '2635381', 'Yes', '20', '30', 'E1', '71.43', '50', '-12.5', 'No', 'No', 'Male', 'Employee Referral', '3', 'L004', '560034', '27', '1', 'D2']
# ['204', '2635429', 'No', '1', '30', 'E1', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Employee Referral', '3', 'L001', '201301', '34', '2', 'D6']
# ['205', '2635526', 'Yes', '7', '30', 'E1', '42.83', '42.83', '0', 'No', 'No', 'Male', 'Employee Referral', '4', 'L001', '201301', '27', '2', 'D8']
# ['206', '2635705', 'Yes', '15', '30', 'E2', '8.33', '12.75', '4.07', 'No', 'No', 'Male', 'Agency', '9', 'L002', '600020', '33', '1', 'D20']
# ['208', '2635749', 'No', '35', '30', 'E1', '215.32', '170.27', '-14.29', 'No', 'No', 'Male', 'Direct', '3', 'L002', '600020', '26', '1', 'D21']
# ['210', '2778998', 'No', '17', '30', 'E1', '233.33', '191.67', '-12.5', 'No', 'No', 'Male', 'Agency', '4', 'L002', '600020', '27', '1', 'D4']
# ['211', '2780352', 'Yes', '58', '30', 'E3', '30.43', '30.43', '0', 'No', 'No', 'Male', 'Agency', '10', 'L004', '560034', '34', '1', 'D4']
# ['213', '2780669', 'Yes', '29', '60', '', '33.33', '266.67', '175', 'No', 'No', 'Male', 'Agency', '9', 'L001', '201301', '32', '1', 'D23']
# ['215', '2780903', 'Yes', '69', '90', 'E2', '32.53', '32.53', '0', 'No', 'No', 'Male', 'Direct', '3', 'L001', '201301', '26', '2', 'D6']
# ['216', '2781322', 'Yes', '6', '90', 'E2', '-11.69', '-11.69', '0', 'No', 'No', 'Male', 'Employee Referral', '7', 'L002', '600020', '32', '4', 'D14']
# ['217', '2786502', 'No', '0', '30', 'E2', '30.26', '35.26', '3.84', 'No', 'No', 'Male', 'Direct', '6', 'L001', '201301', '34', '2', 'D14']
# ['218', '2790302', 'Yes', '1', '30', 'E3', '-12.2', '-12.2', '0', 'No', 'No', 'Male', 'Employee Referral', '10', 'L005', '500004', '36', '2', 'D16']
# ['219', '2793776', 'No', '7', '90', 'E2', '43.79', '36.6', '-5', 'No', 'No', 'Male', 'Agency', '7', 'L004', '560034', '32', '4', 'D18']
# ['221', '2794614', 'No', '0', '30', 'E2', '72.41', '72.41', '0', 'No', 'No', 'Male', 'Agency', '4', 'L004', '560034', '32', '2', 'D22']
# ['222', '2795222', 'Yes', '7', '30', 'E2', '-24.6', '-24.6', '0', 'No', 'No', 'Male', 'Direct', '5', 'L002', '600020', '31', '4', 'D21']
# ['223', '2802356', 'No', '1', '30', 'E1', '37.5', '-50', '-63.64', 'No', 'No', 'Male', 'Employee Referral', '1', 'L001', '201301', '24', '2', 'D18']
# ['224', '2804650', 'Yes', '17', '30', 'E1', '23.08', '30.77', '6.25', 'No', 'No', 'Male', 'Employee Referral', '2', 'L004', '560034', '27', '1', 'D8']
# ['227', '2807929', 'No', '86', '30', 'E1', '-13.19', '-13.19', '0', 'No', 'No', 'Male', 'Direct', '3', 'L002', '600020', '28', '4', 'D17']
# ['228', '2814312', 'Yes', '51', '90', 'E2', '42.84', '42.84', '0', 'No', 'No', 'Male', 'Agency', '6', 'L001', '201301', '29', '2', 'D7']
# ['229', '2814340', 'Yes', '29', '45', 'E3', '37.06', '31.58', '-4', 'No', 'No', 'Male', 'Employee Referral', '5', 'L002', '600020', '32', '2', 'D12']
# ['230', '2814452', 'Yes', '1', '30', 'E2', '37.5', '35', '-1.82', 'No', 'No', 'Male', 'Employee Referral', '3', 'L004', '560034', '30', '2', 'D14']
# ['231', '2819665', 'Yes', '26', '30', 'E2', '42.85', '42.85', '0', 'No', 'No', 'Male', 'Employee Referral', '8', 'L001', '201301', '31', '2', 'D1']
# ['232', '2819712', 'Yes', '0', '30', 'E2', '15.38', '15.38', '0', 'No', 'No', 'Male', 'Direct', '10', 'L004', '560034', '36', '8', 'D16']
# ['233', '2823905', 'No', '50', '60', 'E2', '42.85', '42.85', '0', 'No', 'Yes', 'Male', 'Employee Referral', '5', 'L001', '201301', '29', '2', 'D1']
# ['234', '2824103', 'Yes', '39', '30', 'E1', '-31.06', '-1.52', '42.86', 'No', 'No', 'Male', 'Agency', '5', 'L005', '500004', '29', '1', 'D3']
# ['235', '2826712', 'Yes', '57', '60', 'E2', '34.62', '25', '-7.14', 'No', 'No', 'Male', 'Employee Referral', '7', 'L001', '201301', '31', '2', 'D6']
# ['236', '2828770', 'No', '0', '30', 'E2', '42.85', '42.85', '0', 'No', 'No', 'Male', 'Employee Referral', '4', 'L002', '600020', '26', '2', 'D3']
# ['237', '2828841', 'No', '10', '30', 'E2', '42.85', '42.85', '0', 'No', 'No', 'Male', 'Employee Referral', '4', 'L001', '201301', '29', '2', 'D20']
# ['239', '2834484', 'Yes', '0', '30', 'E1', '-12', '-12', '0', 'No', 'No', 'Male', 'Agency', '1', 'L003', '122107', '24', '2', 'D23']
# ['240', '2834603', 'No', '3', '90', 'E1', '-16.67', '-16.67', '0', 'No', 'No', 'Male', 'Direct', '4', 'L002', '600020', '27', '4', 'D16']
# ['241', '2839728', 'No', '5', '60', 'E2', '-17.07', '-14.63', '2.94', 'No', 'No', 'Male', 'Employee Referral', '12', 'L001', '201301', '31', '2', 'D16']
# ['242', '2840929', 'Yes', '32', '30', 'E2', '57.14', '114.29', '36.36', 'No', 'No', 'Male', 'Direct', '4', 'L002', '600020', '27', '2', 'D1']
# ['243', '2841169', 'Yes', '93', '90', 'E2', '44.44', '33.33', '-7.69', 'No', 'Yes', 'Male', 'Employee Referral', '3', 'L002', '600020', '28', '2', 'D3']
# ['244', '2845533', 'Yes', '30', '30', 'E1', '-16.3', '19.57', '42.86', 'No', 'No', 'Male', 'Agency', '3', 'L005', '500004', '25', '1', 'D12']
# ['245', '2845929', 'Yes', '55', '30', '', '37.5', '25', '-9.09', 'No', 'Yes', 'Female', 'Employee Referral', '3', 'L004', '560034', '25', '2', 'D15']
# ['246', '2846059', 'No', '39', '45', 'E3', '33.33', '236.67', '152.5', 'No', 'No', 'Male', 'Agency', '9', 'L005', '500004', '32', '1', 'D4']
# ['248', '2850795', 'No', '12', '30', 'E1', '-54.04', '-34.34', '42.86', 'No', 'Yes', 'Male', 'Employee Referral', '6', 'L002', '600020', '44', '4', 'D9']
# ['249', '2850802', 'No', '3', '30', 'E2', '15.55', '10.29', '-4.55', 'No', 'No', 'Male', 'Direct', '7', 'L002', '600020', '29', '1', 'D19']
# ['251', '2861481', 'No', '3', '30', 'E1', '114.29', '90.48', '-11.11', 'No', 'No', 'Male', 'Agency', '3', 'L002', '600020', '26', '1', 'D13']
# ['252', '2861532', 'No', '23', '30', 'E1', '212.5', '160.42', '-16.67', 'No', 'Yes', 'Male', 'Agency', '2', 'L002', '600020', '30', '1', 'D15']
# ['254', '2861816', 'No', '11', '60', 'E2', '69.68', '58.37', '-6.67', 'No', 'No', 'Male', 'Direct', '6', 'L002', '600020', '34', '1', 'D6']
# ['255', '2861873', 'No', '0', '30', 'E2', '-36.36', '-36.36', '0', 'No', 'No', 'Male', 'Direct', '9', 'L002', '600020', '32', '7', 'D13']
# ['256', '2861938', 'Yes', '3', '60', 'E3', '35', '45', '7.41', 'No', 'No', 'Male', 'Direct', '8', 'L008', '411002', '30', '2', 'D6']
# ['257', '2863789', 'No', '1', '30', 'E2', '29.41', '35.29', '4.55', 'No', 'No', 'Male', 'Employee Referral', '6', 'L001', '201301', '33', '7', 'D20']
# ['258', '2865940', 'Yes', '71', '60', 'E3', '42.85', '42.85', '0', 'No', 'No', 'Male', 'Employee Referral', '6', 'L001', '201301', '30', '2', 'D13']
# ['260', '2866433', 'Yes', '40', '60', 'E2', '57.14', '39.29', '-11.36', 'No', 'No', 'Female', 'Direct', '7', 'L004', '560034', '32', '4', 'D18']
# ['262', '2926304', 'No', '4', '45', 'E2', '41.03', '21.79', '-13.64', 'No', 'No', 'Male', 'Direct', '7', 'L004', '560034', '34', '4', 'D13']
# ['263', '2930426', 'Yes', '5', '45', 'E1', '-25', '-43.75', '-25', 'Yes', 'No', 'Male', 'Direct', '2', 'L002', '600020', '27', '1', 'D22']
# ['265', '2945577', 'No', '56', '90', 'E2', '66.08', '55', '-6.67', 'No', 'No', 'Male', 'Agency', '8', 'L004', '560034', '30', '4', 'D7']
# ['267', '3029497', 'No', '1', '30', 'E2', '50', '58.33', '5.56', 'No', 'No', 'Male', 'Direct', '3', 'L001', '201301', '27', '2', 'D21']
# ['268', '3029512', 'Yes', '2', '60', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Female', 'Direct', '8', 'L002', '600020', '31', '2', 'D12']
# ['269', '3030928', 'Yes', '15', '60', 'E3', '42.85', '42.85', '0', 'No', 'No', 'Male', 'Employee Referral', '5', 'L001', '201301', '30', '2', 'D8']
# ['271', '3034334', 'Yes', '37', '30', 'E1', '180.9', '124.72', '-20', 'No', 'No', 'Female', 'Agency', '3', 'L002', '600020', '26', '1', 'D20']
# ['272', '3034476', 'Yes', '6', '30', 'E3', '53.85', '50', '-2.5', 'No', 'No', 'Male', 'Employee Referral', '5', 'L001', '201301', '32', '2', 'D3']
# ['274', '3034980', 'No', '0', '30', 'E2', '36.36', '60', '17.33', 'No', 'No', 'Male', 'Direct', '6', 'L004', '560034', '32', '2', 'D8']
# ['275', '3037418', 'No', '40', '30', 'E1', '56.86', '27.45', '-18.75', 'No', 'No', 'Male', 'Direct', '4', 'L004', '560034', '34', '7', 'D21']
# ['277', '3040819', 'No', '18', '30', 'E1', '280.95', '280.95', '0', 'No', 'No', 'Male', 'Direct', '2', 'L002', '600020', '26', '1', 'D12']
# ['279', '3046539', 'No', '12', '30', 'E1', '170.27', '75.68', '-35', 'No', 'No', 'Male', 'Employee Referral', '2', 'L004', '560034', '29', '1', 'D10']
# ['280', '3046652', 'Yes', '1', '60', 'E1', '60', '26', '-21.25', 'No', 'No', 'Male', 'Agency', '4', 'L001', '201301', '28', '1', 'D1']
# ['282', '3108736', 'Yes', '5', '30', 'E3', '42.59', '42.59', '0', 'No', 'No', 'Male', 'Employee Referral', '9', 'L001', '201301', '42', '2', 'D11']
# ['283', '3110300', 'Yes', '15', '30', 'E1', '42.83', '42.83', '0', 'No', 'No', 'Male', 'Employee Referral', '2', 'Null', '600018', '26', '2', 'D16']
# ['284', '3120254', 'Yes', '39', '90', 'E2', '46.24', '46.24', '0', 'No', 'No', 'Male', 'Agency', '6', 'L002', '600020', '37', '1', 'D22']
# ['285', '3188371', 'Yes', '1', '30', 'E1', '44.44', '-41.33', '-59.38', 'No', 'No', 'Female', 'Employee Referral', '1', 'L001', '201301', '24', '2', 'D7']
# ['286', '3200275', 'No', '12', '30', 'E2', '48.15', '33.33', '-10', 'Yes', 'Yes', 'Male', 'Agency', '4', 'L005', '500004', '26', '1', 'D18']
# ['287', '3200724', 'No', '18', '60', 'E2', '45.45', '39.39', '-4.17', 'Yes', 'No', 'Male', 'Direct', '8', 'L001', '201301', '32', '6', 'D18']
# ['288', '3203880', 'No', '7', '30', 'E1', '114.29', '117.86', '1.67', 'No', 'No', 'Male', 'Employee Referral', '2', 'L004', '560034', '25', '1', 'D10']
# ['290', '3204472', 'Yes', '24', '30', 'E1', '-33.33', '-38.89', '-8.33', 'No', 'No', 'Male', 'Employee Referral', '6', 'L002', '600020', '26', '1', 'D6']
# ['291', '3211382', 'No', '4', '30', '', '42.85', '42.85', '0', 'No', 'No', 'Male', 'Agency', '4', 'L004', '560034', '30', '2', 'D22']
# ['292', '3211556', 'Yes', '66', '60', 'E3', '-19.23', '15.38', '42.86', 'No', 'No', 'Male', 'Employee Referral', '13', 'L001', '201301', '35', '1', 'D1']
# ['293', '3215106', 'Yes', '4', '30', 'E1', '203.51', '184.54', '-6.25', 'No', 'No', 'Male', 'Direct', '1', 'L002', '600020', '26', '1', 'D21']
# ['294', '3215514', 'No', '3', '30', 'E1', '-38.4', '-12', '42.86', 'No', 'No', 'Male', 'Employee Referral', '3', 'L002', '600020', '28', '4', 'D15']
# ['295', '3215757', 'Yes', '21', '30', 'E1', '233.33', '127.27', '-31.82', 'No', 'No', 'Male', 'Agency', '5', 'L002', '600020', '27', '1', 'D21']
# ['296', '3221299', 'Yes', '68', '30', 'E2', '44.44', '0', '-30.77', 'No', 'Yes', 'Female', 'Direct', '3', 'L005', '500004', '24', '2', 'D16']
# ['298', '3225344', 'Yes', '3', '30', 'E3', '32.78', '28.63', '-3.13', 'No', 'Yes', 'Male', 'Agency', '12', 'L004', '560034', '35', '4', 'D14']
# ['300', '3225955', 'Yes', '62', '30', 'E1', '40.68', '34.69', '-4.26', 'No', 'No', 'Male', 'Employee Referral', '4', 'L002', '600020', '27', '1', 'D21']
# ['301', '3225969', 'Yes', '15', '30', 'E2', '42.85', '42.85', '0', 'No', 'Yes', 'Male', 'Employee Referral', '5', 'L002', '600020', '30', '2', 'D11']
# ['303', '3226137', 'Yes', '31', '30', 'E1', '40.68', '-10.21', '-36.17', 'No', 'No', 'Male', 'Direct', '2', 'L002', '600020', '27', '1', 'D9']
# ['304', '3226180', 'Yes', '84', '45', 'E2', '42.84', '42.84', '0', 'No', 'No', 'Male', 'Direct', '5', 'L005', '500004', '35', '2', 'D21']
# ['306', '3229762', 'No', '42', '30', 'E1', '50.5', '99', '32.23', 'No', 'No', 'Male', 'Agency', '3', 'L009', '400001', '27', '4', 'D24']
# ['307', '3234247', 'No', '17', '60', 'E3', '57.14', '257.14', '127.27', 'No', 'No', 'Male', 'Direct', '8', 'L004', '560034', '35', '2', 'D17']
# ['310', '3238748', 'No', '0', '90', 'E3', '-21.54', '-21.54', '0', 'No', 'No', 'Male', 'Direct', '13', 'L002', '600020', '40', '1', 'D7']
# ['311', '3239288', 'No', '10', '30', 'E1', '42.83', '42.83', '0', 'No', 'No', 'Male', 'Employee Referral', '2', 'L001', '201301', '27', '2', 'D20']
# ['312', '3243075', 'Yes', '8', '30', 'E2', '-3.23', '-3.23', '0', 'No', 'No', 'Female', 'Agency', '6', 'L002', '600020', '29', '1', 'D20']
# ['313', '3244438', 'Yes', '55', '60', 'E3', '42.85', '42.85', '0', 'No', 'No', 'Male', 'Employee Referral', '6', 'L001', '201301', '32', '2', 'D5']
# ['314', '3245861', 'Yes', '25', '30', 'E2', '42.85', '42.85', '0', 'No', 'Yes', 'Male', 'Employee Referral', '4', 'L002', '600020', '28', '2', 'D4']
# ['315', '3245971', 'Yes', '10', '30', 'E1', '27.78', '20', '-6.09', 'No', 'No', 'Female', 'Employee Referral', '2', 'L002', '600020', '26', '1', 'D21']
# ['316', '3250021', 'No', '3', '30', 'E1', '-20.63', '42.86', '80', 'No', 'Yes', 'Male', 'Agency', '1', 'L002', '600020', '24', '1', 'D6']
# ['317', '3250029', 'Yes', '1', '30', 'E1', '-35.45', '-7.79', '42.86', 'No', 'No', 'Male', 'Agency', '3', 'L002', '600020', '26', '1', 'D6']
# ['318', '3250143', 'Yes', '50', '30', 'E1', '-27.78', '-27.78', '0', 'No', 'No', 'Female', 'Agency', '8', 'L002', '600020', '33', '3', 'D9']
# ['320', '3250941', 'No', '2', '45', 'E2', '37.36', '30.49', '-5', 'No', 'No', 'Male', 'Agency', '7', 'L002', '600020', '32', '4', 'D23']
# ['321', '3251306', 'No', '28', '30', 'E2', '42.84', '42.84', '0', 'No', 'Yes', 'Male', 'Employee Referral', '7', 'L002', '600020', '37', '2', 'D1']
# ['322', '3256827', 'Yes', '26', '30', 'E1', '26.37', '61.69', '27.95', 'No', 'Yes', 'Male', 'Agency', '3', 'L001', '201301', '27', '4', 'D3']
# ['323', '3257382', 'Yes', '40', '60', 'E1', '45', '47.5', '1.72', 'No', 'No', 'Male', 'Direct', '4', 'L001', '201301', '28', '5', 'D20']
# ['324', '3257556', 'Yes', '26', '30', 'E2', '42.85', '42.85', '0', 'No', 'No', 'Male', 'Employee Referral', '6', 'L001', '201301', '30', '2', 'D16']
# ['325', '3257972', 'No', '13', '60', 'E1', '-22.13', '11.25', '42.86', 'No', 'No', 'Male', 'Agency', '2', 'L001', '201301', '25', '5', 'D8']
# ['326', '3258076', 'No', '1', '30', 'E1', '-68.83', '24.68', '300', 'No', 'No', 'Male', 'Agency', '3', 'L002', '600020', '24', '1', 'D7']
# ['327', '3258078', 'No', '3', '30', 'E1', '306.25', '168.75', '-33.85', 'No', 'No', 'Male', 'Agency', '9', 'L002', '600020', '36', '1', 'D2']
# ['328', '3258105', 'Yes', '3', '30', 'E1', '-39.64', '42.86', '136.67', 'No', 'No', 'Male', 'Agency', '1', 'L002', '600020', '27', '1', 'D2']
# ['329', '3258125', 'Yes', '5', '30', 'E1', '359.77', '244.83', '-25', 'No', 'No', 'Male', 'Direct', '3', 'L002', '600020', '26', '1', 'D21']
# ['331', '3262701', 'Yes', '7', '30', 'E1', '212.5', '212.5', '0', 'No', 'No', 'Female', 'Agency', '2', 'L002', '600020', '25', '1', 'D4']
# ['332', '3263017', 'Yes', '9', '30', 'E2', '33.33', '16.67', '-12.5', 'No', 'No', 'Male', 'Direct', '10', 'L002', '600020', '35', '1', 'D5']
# ['333', '3264071', 'Yes', '40', '30', 'E3', '-30.43', '-28.26', '3.13', 'No', 'No', 'Male', 'Direct', '13', 'L002', '600020', '36', '3', 'D17']
# ['334', '3267491', 'No', '1', '30', 'E1', '80.56', '69.44', '-6.15', 'No', 'No', 'Male', 'Employee Referral', '1', 'L004', '560034', '30', '1', 'D17']
# ['336', '3267878', 'No', '28', '60', 'E1', '291.3', '165.22', '-32.22', 'No', 'No', 'Male', 'Agency', '3', 'L002', '600020', '28', '4', 'D22']
# ['338', '3267960', 'Yes', '64', '60', 'E2', '42.84', '42.84', '0', 'No', 'No', 'Male', 'Employee Referral', '7', 'L002', '600020', '35', '2', 'D3']
# ['339', '3272381', 'Yes', '107', '30', 'E1', '43.59', '41.03', '-1.79', 'No', 'No', 'Male', 'Direct', '4', 'L004', '560034', '26', '1', 'D23']
# ['340', '3278272', 'Yes', '27', '30', 'E3', '42.85', '42.85', '0', 'No', 'Yes', 'Male', 'Employee Referral', '8', 'L002', '600020', '33', '2', 'D9']
# ['342', '3280954', 'Yes', '29', '30', 'E2', '42.84', '42.84', '0', 'No', 'Yes', 'Male', 'Employee Referral', '4', 'L002', '600020', '32', '2', 'D6']
# ['343', '3283933', 'No', '0', '30', 'E1', '50', '50', '0', 'No', 'No', 'Male', 'Employee Referral', '4', 'L004', '560034', '26', '4', 'D6']
# ['344', '3284172', 'Yes', '14', '30', 'E1', '216.67', '195.83', '-6.58', 'No', 'No', 'Male', 'Direct', '3', 'L002', '600020', '25', '5', 'D20']
# ['345', '3284288', 'Yes', '4', '30', 'E1', '42.84', '42.84', '0', 'No', 'No', 'Female', 'Employee Referral', '2', 'L001', '201301', '24', '2', 'D6']
# ['348', '3288600', 'Yes', '78', '90', 'E2', '-21.92', '-21.92', '0', 'No', 'No', 'Male', 'Direct', '8', 'L002', '600020', '31', '4', 'D1']
# ['350', '3290646', 'No', '0', '30', 'E2', '100', '200', '50', 'No', 'No', 'Male', 'Direct', '2', 'L001', '201301', '34', '2', 'D14']
# ['351', '3293535', 'Yes', '4', '30', 'E2', '-23.29', '9.59', '42.86', 'Yes', 'No', 'Male', 'Agency', '6', 'L002', '600020', '38', '1', 'D9']
# ['353', '3293720', 'No', '30', '30', 'E1', '-14.97', '42.86', '68', 'No', 'No', 'Male', 'Agency', '1', 'L004', '560034', '26', '2', 'D11']
# ['354', '3294274', 'No', '32', '45', 'E1', '36.84', '32.89', '-2.88', 'No', 'Yes', 'Female', 'Agency', '4', 'L002', '600020', '34', '1', 'D22']
# ['355', '3294297', 'Yes', '39', '30', 'E1', '33.33', '66.67', '25', 'No', 'No', 'Male', 'Direct', '1', 'L002', '600020', '24', '2', 'D1']
# ['356', '3294316', 'Yes', '58', '30', 'E1', '33.33', '66.67', '25', 'No', 'No', 'Male', 'Direct', '1', 'L002', '600020', '24', '2', 'D8']
# ['357', '3294384', 'Yes', '33', '30', 'E2', '57.14', '57.14', '0', 'No', 'Yes', 'Male', 'Employee Referral', '3', 'L002', '600020', '24', '2', 'D5']
# ['358', '3300178', 'No', '14', '30', 'E1', '-19.09', '-19.09', '0', 'No', 'No', 'Male', 'Direct', '3', 'L002', '600020', '25', '3', 'D9']
# ['359', '3300192', 'No', '16', '30', 'E2', '22.22', '48.89', '21.82', 'No', 'No', 'Male', 'Direct', '5', 'L004', '560034', '30', '2', 'D12']
# ['360', '3300563', 'Yes', '29', '30', '', '-30', '-30.6', '-0.85', 'No', 'No', 'Male', 'Employee Referral', '8', 'L001', '201301', '33', '5', 'D19']
# ['361', '3300715', 'Yes', '20', '60', 'E2', '42.85', '42.85', '0', 'No', 'No', 'Male', 'Agency', '4', 'L001', '201301', '27', '2', 'D12']
# ['362', '3300802', 'Yes', '26', '45', 'E1', '-18.27', '-18.27', '0', 'Yes', 'No', 'Male', 'Agency', '2', 'L002', '600020', '24', '1', 'D4']
# ['363', '3300828', 'Yes', '28', '30', 'E2', '42.85', '42.85', '0', 'No', 'Yes', 'Male', 'Employee Referral', '9', 'L002', '600020', '36', '2', 'D1']
# ['364', '3302340', 'Yes', '22', '60', 'E2', '42.84', '42.84', '0', 'No', 'No', 'Male', 'Employee Referral', '2', 'L001', '201301', '28', '2', 'D23']
# ['365', '3304533', 'Yes', '4', '30', 'E1', '-62.5', '-11.25', '136.67', 'No', 'Yes', 'Female', 'Agency', '2', 'L001', '201301', '27', '5', 'D11']
# ['366', '3305244', 'Yes', '8', '30', 'E2', '-10.53', '-10.53', '0', 'No', 'No', 'Male', 'Direct', '8', 'L004', '560034', '30', '2', 'D12']
# ['368', '3311520', 'Yes', '49', '30', 'E2', '294.74', '228.95', '-16.67', 'No', 'No', 'Male', 'Direct', '5', 'L004', '560034', '37', '7', 'D22']
# ['369', '3318393', 'Yes', '0', '30', 'E1', '92.54', '80.51', '-6.25', 'No', 'No', 'Male', 'Direct', '3', 'Null', '560034', '23', '2', 'D14']
# ['370', '3321416', 'Yes', '1', '30', 'E2', '46.67', '46.67', '0', 'No', 'No', 'Male', 'Direct', '11', 'L009', '400001', '39', '3', 'D9']
# ['371', '3322390', 'Yes', '37', '60', 'E1', '80.56', '69.44', '-6.15', 'No', 'No', 'Male', 'Employee Referral', '3', 'L004', '560034', '26', '6', 'D11']
# ['372', '3327789', 'No', '0', '30', 'E2', '200', '180', '-6.67', 'No', 'No', 'Male', 'Employee Referral', '2', 'L001', '201301', '24', '2', 'D18']
# ['373', '3327838', 'No', '2', '30', 'E2', '150', '133.33', '-6.67', 'No', 'No', 'Male', 'Employee Referral', '1', 'L001', '201301', '25', '2', 'D6']
# ['374', '3328005', 'Yes', '92', '90', 'E1', '23.46', '29.63', '5', 'No', 'No', 'Male', 'Direct', '6', 'L004', '560034', '30', '7', 'D19']
# ['375', '3328526', 'No', '1', '0', 'E1', '-12.05', '25.65', '42.86', 'No', 'No', 'Female', 'Employee Referral', '2', 'L004', '560034', '27', '1', 'D15']
# ['376', '3328640', 'No', '6', '60', 'E2', '53.33', '53.33', '0', 'No', 'No', 'Male', 'Agency', '7', 'L001', '201301', '30', '3', 'D11']
# ['379', '3338018', 'Yes', '1', '30', 'E2', '42.84', '42.84', '0', 'No', 'No', 'Male', 'Agency', '3', 'L001', '201301', '24', '2', 'D24']
# ['380', '3342223', 'Yes', '9', '30', 'E2', '42.84', '42.84', '0', 'No', 'No', 'Male', 'Agency', '2', 'L001', '201301', '28', '2', 'D5']
# ['381', '3342678', 'Yes', '3', '30', 'E3', '57.14', '28.57', '-18.18', 'No', 'No', 'Female', 'Employee Referral', '7', 'L001', '201301', '29', '2', 'D8']
# ['382', '3346442', 'Yes', '24', '30', 'E1', '42.84', '42.84', '0', 'No', 'No', 'Male', 'Employee Referral', '1', 'L001', '201301', '24', '2', 'D15']
# ['383', '3347772', 'Yes', '3', '30', 'E1', '42.83', '42.83', '0', 'No', 'No', 'Male', 'Employee Referral', '2', 'L001', '201301', '27', '2', 'D12']
# ['384', '3347826', 'No', '9', '30', 'E1', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Employee Referral', '1', 'L001', '201301', '21', '2', 'D22']
# ['385', '3348191', 'Yes', '34', '60', 'E3', '-10.53', '-11.69', '-1.3', 'Yes', 'Yes', 'Male', 'Direct', '5', 'L001', '201301', '34', '2', 'D4']
# ['386', '3351261', 'No', '0', '0', 'E2', '33.33', '266.67', '175', 'No', 'No', 'Male', 'Direct', '8', 'L002', '600020', '34', '2', 'D9']
# ['387', '3351640', 'Yes', '39', '30', 'E1', '44.44', '-26.67', '-49.23', 'No', 'No', 'Male', 'Direct', '2', 'L004', '560034', '27', '2', 'D20']
# ['388', '3351807', 'Yes', '15', '30', 'E2', '42.84', '42.84', '0', 'No', 'No', 'Male', 'Employee Referral', '1', 'L001', '201301', '26', '2', 'D3']
# ['389', '3351848', 'No', '3', '30', 'E1', '36.93', '42.86', '4.33', 'No', 'No', 'Male', 'Direct', '2', 'L005', '500004', '25', '2', 'D6']
# ['390', '3352340', 'Yes', '4', '0', 'E2', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Employee Referral', '7', 'L001', '201301', '31', '2', 'D3']
# ['391', '3355586', 'Yes', '9', '30', 'E3', '-17.65', '-17.65', '0', 'No', 'No', 'Male', 'Direct', '15', 'L001', '201301', '36', '2', 'D21']
# ['392', '3355597', 'Yes', '14', '30', 'E1', '89.19', '62.16', '-14.29', 'No', 'No', 'Female', 'Agency', '4', 'L001', '201301', '28', '5', 'D4']
# ['393', '3356490', 'No', '4', '30', 'E2', '44.44', '-33.33', '-53.85', 'No', 'No', 'Male', 'Direct', '2', 'L009', '400001', '26', '2', 'D9']
# ['394', '3356959', 'No', '42', '30', 'E1', '227.87', '145.9', '-25', 'No', 'No', 'Male', 'Employee Referral', '3', 'L002', '600020', '26', '1', 'D6']
# ['395', '3374169', 'No', '61', '30', 'E3', '30', '169.44', '107.26', 'No', 'No', 'Male', 'Direct', '8', 'L002', '600020', '34', '2', 'D16']
# ['396', '3374257', 'No', '61', '30', 'E2', '50', '0', '-33.33', 'No', 'No', 'Male', 'Direct', '2', 'L004', '560034', '29', '2', 'D10']
# ['398', '3377182', 'Yes', '23', '90', 'E2', '53.85', '46.15', '-5', 'No', 'No', 'Female', 'Employee Referral', '6', 'L002', '600020', '31', '1', 'D3']
# ['399', '3377286', 'No', '0', '30', 'E1', '76.47', '76.47', '0', 'No', 'No', 'Male', 'Direct', '2', 'L001', '201301', '23', '1', 'D1']
# ['400', '3377474', 'Yes', '79', '90', 'E2', '20', '13', '-5.83', 'No', 'No', 'Female', 'Direct', '7', 'L001', '201301', '33', '6', 'D16']
# ['401', '3379707', 'No', '34', '30', 'E1', '266.67', '166.67', '-27.27', 'No', 'No', 'Male', 'Agency', '3', 'L001', '201301', '28', '5', 'D7']
# ['402', '3379843', 'No', '17', '0', '', '-12.04', '-12.04', '0', 'No', 'No', 'Male', 'Agency', '2', 'L002', '600020', '28', '2', 'D3']
# ['403', '3382002', 'Yes', '8', '30', 'E1', '60.49', '38.27', '-13.85', 'No', 'No', 'Male', 'Direct', '4', 'L001', '201301', '26', '5', 'D4']
# ['404', '3382722', 'No', '64', '30', 'E1', '240', '150', '-26.47', 'No', 'Yes', 'Male', 'Direct', '1', 'L002', '600020', '26', '1', 'D15']
# ['411', '3418495', 'No', '3', '0', 'E1', '-16.67', '-25', '-10', 'No', 'No', 'Male', 'Direct', '4', 'L004', '560034', '30', '6', 'D18']
# ['412', '3423899', 'Yes', '20', '30', 'E1', '57.14', '5.71', '-32.73', 'No', 'No', 'Male', 'Direct', '3', 'L001', '201301', '24', '5', 'D3']
# ['413', '3423964', 'No', '33', '30', 'E1', '80.56', '23.61', '-31.54', 'No', 'No', 'Male', 'Direct', '4', 'L001', '201301', '32', '5', 'D22']
# ['414', '3424007', 'Yes', '46', '30', 'E1', '44.44', '-20', '-44.62', 'No', 'No', 'Male', 'Direct', '3', 'L001', '201301', '25', '5', 'D22']
# ['415', '3424549', 'Yes', '77', '30', 'E1', '80', '78', '-1.11', 'No', 'No', 'Female', 'Direct', '3', 'L001', '201301', '25', '5', 'D6']
# ['416', '3424789', 'No', '14', '30', 'E1', '24.53', '18.31', '-5', 'Yes', 'Yes', 'Male', 'Agency', '4', 'L004', '560034', '27', '1', 'D4']
# ['417', '3425046', 'No', '0', '0', 'E1', '-33.33', '-23.81', '14.29', 'Yes', 'Yes', 'Female', 'Direct', '4', 'L002', '600020', '27', '1', 'D21']
# ['418', '3428591', 'Yes', '21', '90', 'E2', '15.38', '15.38', '0', 'Yes', 'No', 'Male', 'Direct', '8', 'L002', '600020', '30', '1', 'D15']
# ['419', '3429009', 'No', '16', '0', 'E1', '2.08', '225', '218.37', 'No', 'No', 'Male', 'Employee Referral', '7', 'L002', '600020', '31', '7', 'D1']
# ['420', '3429992', 'Yes', '20', '30', 'E1', '28.89', '28.89', '0', 'No', 'No', 'Male', 'Direct', '3', 'L002', '600020', '27', '5', 'D13']
# ['422', '3435024', 'No', '11', '30', 'E1', '257.14', '471.43', '60', 'Yes', 'Yes', 'Male', 'Agency', '3', 'L002', '600020', '28', '7', 'D6']
# ['427', '3458547', 'Yes', '9', '30', 'E2', '38.89', '31.94', '-5', 'No', 'Yes', 'Male', 'Direct', '7', 'L005', '500004', '36', '3', 'D11']
# ['428', '3459128', 'Yes', '23', '60', 'E1', '59.57', '46.81', '-8', 'Yes', 'Yes', 'Male', 'Employee Referral', '4', 'L004', '560034', '26', '1', 'D11']
# ...
# ['12044', '3700536', 'No', '4', '30', 'E1', '13.33', '-6.67', '-17.65', 'Yes', 'Yes', 'Male', 'Direct', '3', 'L002', '600020', '34', '1', 'D3']
# ['12045', '3700662', 'No', '1', '0', 'E3', '44.44', '300', '176.92', 'No', 'No', 'Male', 'Employee Referral', '11', 'L002', '600020', '34', '8', 'D9']
# ['12049', '3706704', 'No', '17', '30', 'E1', '33.33', '15', '-13.75', 'No', 'No', 'Male', 'Agency', '4', 'L002', '600020', '34', '1', 'D6']
# ['12050', '3706995', 'No', '2', '45', 'E1', '56.25', '56.25', '0', 'No', 'Yes', 'Male', 'Direct', '3', 'L002', '600020', '34', '6', 'D2']
# ['12052', '3707015', 'Yes', '2', '30', 'E1', '20', '30', '8.33', 'No', 'Yes', 'Male', 'Direct', '3', 'L005', '500004', '34', '8', 'D9']
# ['12054', '3707040', 'Yes', '11', '30', 'E1', '26.63', '26.63', '0', 'Yes', 'No', 'Male', 'Direct', '4', 'L004', '560034', '34', '7', 'D8']
# ['12065', '3707510', 'No', '3', '45', 'E1', '100', '62.5', '-18.75', 'No', 'No', 'Male', 'Direct', '4', 'L004', '560034', '34', '6', 'D10']
# ['12067', '3707763', 'No', '23', '30', 'E1', '87.5', '66.67', '-11.11', 'No', 'Yes', 'Male', 'Employee Referral', '3', 'L008', '411002', '34', '1', 'D10']
# ['12070', '3710680', 'No', '7', '30', 'E2', '80', '132', '28.89', 'No', 'No', 'Male', 'Employee Referral', '4', 'L001', '201301', '34', '2', 'D11']
# ['12072', '3714121', 'No', '3', '30', 'E1', '53.98', '41.14', '-8.33', 'No', 'No', 'Male', 'Employee Referral', '2', 'L001', '201301', '34', '2', 'D2']
# ['12073', '3714354', 'No', '2', '0', 'E1', '42.86', '42.86', '0', 'No', 'No', 'Female', 'Employee Referral', '2', 'L004', '560034', '34', '2', 'D9']
# ['12075', '3714640', 'No', '4', '0', 'E1', '25', '25', '0', 'No', 'No', 'Male', 'Employee Referral', '3', 'L001', '201301', '34', '2', 'D5']
# ['12076', '3714991', 'Yes', '17', '0', 'E1', '40', '40', '0', 'Yes', 'Yes', 'Male', 'Direct', '4', 'L005', '500004', '34', '6', 'D22']
# ['12077', '3715038', 'Yes', '4', '30', 'E1', '33.33', '12.5', '-15.63', 'No', 'Yes', 'Male', 'Direct', '3', 'L005', '500004', '34', '6', 'D6']
# ['12078', '3715080', 'No', '1', '30', 'E1', '53.85', '53.85', '0', 'No', 'No', 'Male', 'Direct', '1', 'L001', '201301', '34', '2', 'D15']
# ['12079', '3715223', 'No', '4', '0', 'E2', '10.29', '10.29', '0', 'No', 'No', 'Female', 'Direct', '8', 'L002', '600020', '34', '1', 'D10']
# ['12080', '3715259', 'No', '4', '0', 'E1', '32.28', '42.86', '8', 'No', 'No', 'Male', 'Direct', '1', 'L002', '600020', '34', '2', 'D11']
# ['12093', '3720977', 'Yes', '7', '30', 'E2', '23.08', '38.46', '12.5', 'No', 'Yes', 'Male', 'Direct', '7', 'L005', '500004', '34', '8', 'D16']
# ['12094', '3720998', 'No', '3', '0', 'E1', '100', '100', '0', 'No', 'No', 'Male', 'Employee Referral', '1', 'L006', '700027', '34', '2', 'D17']
# ['12095', '3721007', 'Yes', '11', '0', 'E3', '5.96', '0.25', '-5.39', 'No', 'No', 'Male', 'Direct', '8', 'L002', '600020', '34', '2', 'D21']
# ['12097', '3721105', 'No', '4', '0', 'E1', '44.23', '16.99', '-18.89', 'No', 'No', 'Male', 'Direct', '5', 'L005', '500004', '34', '6', 'D1']
# ['12103', '3721335', 'Yes', '10', '30', 'E3', '40', '260', '157.14', 'Yes', 'Yes', 'Male', 'Direct', '10', 'L002', '600020', '34', '8', 'D13']
# ['12109', '3721720', 'No', '6', '60', 'E1', '56.25', '39.06', '-11', 'No', 'Yes', 'Male', 'Direct', '3', 'L002', '600020', '34', '1', 'D8']
# ['12112', '3721993', 'No', '13', '30', 'E2', '20.59', '20.59', '0', 'No', 'No', 'Female', 'Employee Referral', '4', 'L001', '201301', '34', '2', 'D21']
# ['12113', '3722046', 'No', '2', '30', 'E1', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Direct', '3', 'L001', '201301', '34', '6', 'D19']
# ['12114', '3722173', 'Yes', '3', '30', 'E2', '23.81', '19.05', '-3.85', 'Yes', 'No', 'Female', 'Employee Referral', '9', 'L002', '600020', '34', '8', 'D4']
# ['12115', '3722278', 'No', '7', '0', 'E2', '40', '80', '28.57', 'No', 'No', 'Male', 'Direct', '7', 'L005', '500004', '34', '6', 'D15']
# ['12116', '3722382', 'Yes', '1', '30', 'E2', '73.8', '28.34', '-26.15', 'No', 'No', 'Male', 'Direct', '3', 'L009', '400001', '34', '2', 'D17']
# ['12117', '3722422', 'Yes', '18', '30', 'E3', '12.5', '9.38', '-2.78', 'Yes', 'No', 'Male', 'Employee Referral', '13', 'L002', '600020', '34', '8', 'D12']
# ['12119', '3726559', 'No', '1', '0', 'E1', '50', '37.5', '-8.33', 'No', 'No', 'Male', 'Employee Referral', '2', 'L003', '122107', '34', '2', 'D13']
# ['12122', '3727613', 'Yes', '2', '30', 'E1', '40', '30', '-7.14', 'No', 'No', 'Male', 'Agency', '4', 'L001', '201301', '34', '1', 'D24']
# ['12123', '3728012', 'Yes', '10', '0', 'E1', '37.78', '33.33', '-3.23', 'No', 'No', 'Male', 'Employee Referral', '3', 'L001', '201301', '34', '1', 'D20']
# ['12124', '3728327', 'Yes', '14', '90', 'E1', '35.42', '29.17', '-4.62', 'No', 'No', 'Male', 'Direct', '5', 'L001', '201301', '34', '5', 'D3']
# ['12125', '3728462', 'Yes', '6', '0', 'E1', '87.5', '50', '-20', 'No', 'No', 'Male', 'Direct', '3', 'L004', '560034', '34', '6', 'D2']
# ['12126', '3728613', 'Yes', '12', '0', 'E1', '44.44', '51.11', '4.62', 'No', 'No', 'Female', 'Direct', '4', 'L005', '500004', '34', '6', 'D20']
# ['12128', '3728943', 'Yes', '2', '30', 'E1', '12.5', '12.5', '0', 'Yes', 'Yes', 'Male', 'Direct', '4', 'L009', '400001', '34', '8', 'D8']
# ['12129', '3732796', 'No', '1', '30', 'E1', '33.33', '20', '-10', 'No', 'No', 'Female', 'Direct', '1', 'L001', '201301', '34', '2', 'D22']
# ['12131', '3732973', 'Yes', '2', '0', 'E1', '38.89', '20', '-13.6', 'No', 'No', 'Male', 'Agency', '1', 'L002', '600020', '34', '2', 'D20']
# ['12132', '3733017', 'No', '0', '30', 'E2', '50', '240', '126.67', 'No', 'Yes', 'Male', 'Agency', '7', 'L002', '600020', '34', '2', 'D15']
# ['12133', '3733027', 'No', '0', '0', 'E1', '100', '140', '20', 'No', 'No', 'Male', 'Agency', '1', 'L004', '560034', '34', '2', 'D8']
# ['12134', '3737201', 'No', '2', '30', 'E1', '54.55', '5.45', '-31.76', 'No', 'No', 'Male', 'Direct', '4', 'L005', '500004', '34', '6', 'D1']
# ['12135', '3737337', 'No', '1', '0', 'E1', '71.43', '71.43', '0', 'No', 'No', 'Male', 'Agency', '1', 'L002', '600020', '34', '2', 'D16']
# ['12136', '3737574', 'Yes', '9', '30', 'E1', '70', '20', '-29.41', 'No', 'No', 'Male', 'Direct', '4', 'L005', '500004', '34', '6', 'D6']
# ['12137', '3737741', 'No', '0', '0', 'E1', '50', '37.5', '-8.33', 'No', 'No', 'Male', 'Agency', '1', 'L002', '600020', '34', '2', 'D11']
# ['12138', '3737746', 'No', '0', '30', 'E1', '50', '25', '-16.67', 'No', 'No', 'Male', 'Employee Referral', '1', 'L002', '600020', '34', '2', 'D1']
# ['12139', '3737752', 'No', '1', '0', 'E1', '50', '37.5', '-8.33', 'No', 'No', 'Female', 'Agency', '1', 'L004', '560034', '34', '2', 'D12']
# ['12140', '3737804', 'No', '3', '30', 'E1', '38.81', '23.94', '-10.71', 'No', 'No', 'Male', 'Agency', '1', 'L002', '600020', '34', '2', 'D9']
# ['12144', '3738246', 'No', '3', '0', 'E1', '20', '20', '0', 'No', 'Yes', 'Male', 'Agency', '3', 'L002', '600020', '34', '2', 'D17']
# ['12145', '3738377', 'No', '1', '0', 'E2', '39.86', '35.66', '-3', 'No', 'Yes', 'Male', 'Direct', '6', 'L005', '500004', '34', '4', 'D2']
# ['12149', '3738652', 'Yes', '1', '0', 'E1', '60.49', '45.68', '-9.23', 'No', 'Yes', 'Male', 'Agency', '3', 'L002', '600020', '34', '1', 'D16']
# ['12150', '3738944', 'No', '5', '30', 'E1', '20', '12', '-6.67', 'No', 'No', 'Male', 'Direct', '3', 'L003', '122107', '34', '2', 'D12']
# ['12151', '3739022', 'Yes', '4', '0', 'E1', '50', '65', '10', 'No', 'No', 'Male', 'Employee Referral', '3', 'L002', '600020', '34', '2', 'D18']
# ['12154', '3744460', 'No', '16', '30', 'E1', '60.49', '45.68', '-9.23', 'No', 'Yes', 'Male', 'Agency', '4', 'L002', '600020', '34', '1', 'D4']
# ['12156', '3745231', 'No', '2', '0', 'E2', '33.33', '40', '5', 'No', 'No', 'Male', 'Agency', '8', 'L005', '500004', '34', '6', 'D9']
# ['12159', '3746127', 'No', '1', '30', 'E2', '50.3', '46.29', '-2.67', 'Yes', 'No', 'Male', 'Direct', '9', 'L001', '201301', '34', '5', 'D16']
# ['12160', '3746228', 'No', '6', '0', 'E2', '46.4', '31.76', '-10', 'No', 'No', 'Male', 'Direct', '4', 'L001', '201301', '34', '2', 'D5']
# ['12164', '3746555', 'No', '1', '0', 'E1', '50', '62.5', '8.33', 'No', 'No', 'Female', 'Employee Referral', '4', 'L004', '560034', '34', '2', 'D8']
# ['12165', '3746653', 'No', '1', '0', 'E1', '85.19', '64.35', '-11.25', 'No', 'No', 'Female', 'Employee Referral', '2', 'L004', '560034', '34', '1', 'D22']
# ['12166', '3751754', 'Yes', '0', '0', 'E2', '75', '57.5', '-10', 'No', 'No', 'Male', 'Agency', '2', 'L001', '201301', '34', '2', 'D1']
# ['12172', '3752710', 'No', '5', '30', 'E3', '9.76', '24.09', '13.06', 'Yes', 'No', 'Male', 'Agency', '11', 'L002', '600020', '34', '1', 'D4']
# ['12174', '3757762', 'No', '7', '45', 'E2', '44.93', '44.93', '0', 'No', 'No', 'Male', 'Direct', '8', 'L002', '600020', '34', '1', 'D18']
# ['12180', '3758488', 'Yes', '4', '0', 'E1', '50', '25', '-16.67', 'No', 'No', 'Female', 'Employee Referral', '1', 'L002', '600020', '34', '2', 'D19']
# ['12181', '3758618', 'No', '1', '0', 'E2', '42.86', '42.86', '0', 'No', 'Yes', 'Male', 'Direct', '5', 'L002', '600020', '34', '2', 'D12']
# ['12183', '3758699', 'No', '7', '0', 'E2', '30', '30', '0', 'No', 'No', 'Female', 'Employee Referral', '9', 'L009', '400001', '34', '4', 'D13']
# ['12184', '3758707', 'No', '2', '0', 'E1', '107.55', '88.68', '-9.09', 'No', 'Yes', 'Male', 'Agency', '3', 'L004', '560034', '34', '1', 'D18']
# ['12187', '3758805', 'No', '6', '0', 'E1', '13.4', '13.4', '0', 'No', 'No', 'Male', 'Agency', '5', 'L004', '560034', '34', '1', 'D16']
# ['12189', '3758899', 'Yes', '8', '60', 'E3', '28.26', '28.26', '0', 'No', 'No', 'Male', 'Direct', '9', 'L002', '600020', '34', '1', 'D1']
# ['12190', '3759268', 'Yes', '2', '0', 'E1', '31.15', '31.15', '0', 'No', 'No', 'Male', 'Direct', '5', 'L001', '201301', '34', '6', 'D18']
# ['12191', '3759365', 'No', '4', '45', 'E1', '55.17', '55.17', '0', 'No', 'No', 'Female', 'Employee Referral', '5', 'L008', '411002', '34', '1', 'D24']
# ['12192', '3759492', 'No', '4', '30', 'E2', '97.67', '74.42', '-11.76', 'No', 'No', 'Male', 'Employee Referral', '7', 'L002', '600020', '34', '1', 'D23']
# ['12193', '3759772', 'Yes', '16', '0', 'E1', '25', '18.06', '-5.56', 'No', 'No', 'Male', 'Employee Referral', '1', 'L001', '201301', '34', '2', 'D19']
# ['12199', '3763262', 'No', '2', '0', 'E2', '31.94', '31.94', '0', 'No', 'Yes', 'Male', 'Employee Referral', '4', 'L002', '600020', '34', '2', 'D2']
# ['12201', '3763431', 'Yes', '8', '0', 'E1', '33.33', '20', '-10', 'No', 'No', 'Female', 'Direct', '1', 'L001', '201301', '34', '2', 'D3']
# ['12205', '3764337', 'No', '9', '0', 'E2', '60', '130', '43.75', 'No', 'No', 'Male', 'Direct', '5', 'L005', '500004', '34', '6', 'D20']
# ['12207', '3764613', 'No', '7', '30', 'E1', '31.58', '22.81', '-6.67', 'No', 'Yes', 'Male', 'Direct', '2', 'L001', '201301', '34', '5', 'D19']
# ['12209', '3766450', 'No', '0', '0', 'E1', '42.11', '31.58', '-7.41', 'No', 'No', 'Male', 'Direct', '3', 'L002', '600020', '34', '1', 'D3']
# ['12210', '3772066', 'Yes', '3', '0', 'E3', '0', '-2.86', '-2.86', 'No', 'Yes', 'Male', 'Direct', '11', 'L005', '500004', '34', '6', 'D2']
# ['12211', '3772180', 'Yes', '1', '0', 'E1', '73.27', '60.89', '-7.14', 'Yes', 'No', 'Male', 'Agency', '3', 'L002', '600020', '34', '1', 'D13']
# ['12212', '3772216', 'No', '2', '30', 'E1', '38.89', '63.89', '18', 'No', 'No', 'Male', 'Agency', '3', 'L002', '600020', '34', '1', 'D12']
# ['12213', '3772228', 'No', '1', '0', 'E1', '48.57', '48.57', '0', 'No', 'No', 'Male', 'Agency', '3', 'L004', '560034', '34', '1', 'D15']
# ['12220', '3773789', 'No', '9', '0', 'E2', '83.33', '83.33', '0', 'No', 'No', 'Male', 'Direct', '6', 'L009', '400001', '34', '6', 'D2']
# ['12222', '3778365', 'Yes', '13', '60', 'E2', '1.27', '0.77', '-0.49', 'No', 'No', 'Male', 'Direct', '6', 'L001', '201301', '34', '2', 'D24']
# ['12230', '3779918', 'No', '5', '0', 'E2', '50', '50', '0', 'No', 'No', 'Male', 'Employee Referral', '7', 'L002', '600020', '34', '1', 'D24']
# ['12232', '3781517', 'No', '7', '0', 'E2', '28.57', '57.14', '22.22', 'No', 'No', 'Female', 'Employee Referral', '8', 'L001', '201301', '34', '8', 'D5']
# ['12236', '3785141', 'Yes', '7', '0', 'E0', '80', '80', '0', 'No', 'No', 'Male', 'Direct', '1', 'L002', '600020', '34', '7', 'D12']
# ['12239', '3785313', 'No', '1', '0', 'E1', '0', '-10', '-10', 'No', 'No', 'Male', 'Direct', '1', 'L004', '560034', '34', '2', 'D9']
# ['12241', '3785527', 'No', '0', '0', 'E1', '0', '0', '0', 'No', 'No', 'Male', 'Agency', '6', 'L002', '600020', '34', '1', 'D4']
# ['12243', '3785691', 'Yes', '12', '30', 'E1', '40', '10', '-21.43', 'No', 'No', 'Male', 'Direct', '6', 'L005', '500004', '34', '6', 'D9']
# ['12244', '3786087', 'No', '2', '0', 'E2', '10.29', '10.29', '0', 'No', 'Yes', 'Male', 'Direct', '2', 'L002', '600020', '34', '2', 'D8']
# ['12245', '3786517', 'No', '4', '30', 'E1', '75', '71.46', '-2.02', 'No', 'No', 'Male', 'Direct', '5', 'L001', '201301', '34', '2', 'D9']
# ['12246', '3786639', 'No', '2', '0', 'E1', '42.86', '42.86', '0', 'No', 'No', 'Male', 'Employee Referral', '0', 'L009', '400001', '34', '4', 'D21']
# ['12247', '3791441', 'No', '1', '0', 'E1', '48.81', '48.81', '0', 'No', 'No', 'Male', 'Employee Referral', '1', 'L004', '560034', '34', '7', 'D15']
# ['12251', '3796690', 'No', '10', '30', 'E1', '53.85', '53.85', '0', 'No', 'No', 'Male', 'Direct', '3', 'L001', '201301', '34', '6', 'D17']
# ['12253', '3796931', 'No', '1', '30', 'E2', '35.2', '35.2', '0', 'No', 'No', 'Male', 'Direct', '3', 'L001', '201301', '34', '2', 'D22']
# ['12254', '3796981', 'No', '2', '0', 'E3', '38.89', '38.89', '0', 'No', 'No', 'Male', 'Employee Referral', '8', 'L002', '600020', '34', '2', 'D20']
# ['12266', '3797489', 'Yes', '2', '0', 'E1', '21.43', '-14.29', '-29.41', 'No', 'No', 'Female', 'Direct', '4', 'L004', '560034', '34', '6', 'D23']
# ['12271', '3798484', 'No', '4', '0', 'E1', '10', '10', '0', 'No', 'No', 'Male', 'Employee Referral', '3', 'L002', '600020', '34', '2', 'D16']
# ['12280', '3802744', 'Yes', '2', '0', 'E1', '15.38', '15.38', '0', 'No', 'No', 'Male', 'Agency', '1', 'L002', '600020', '34', '2', 'D23']
# ['12285', '3807061', 'No', '6', '0', 'E2', '45.52', '45.52', '0', 'No', 'No', 'Female', 'Agency', '7', 'L002', '600020', '34', '1', 'D3']
# ['12286', '3807072', 'No', '0', '0', 'E1', '6.15', '6.15', '0', 'Yes', 'No', 'Male', 'Agency', '4', 'L002', '600020', '34', '1', 'D6']
# ['12289', '3807143', 'Yes', '0', '0', 'E1', '87.5', '118.75', '16.67', 'No', 'No', 'Female', 'Direct', '2', 'L002', '600020', '34', '1', 'D5']
# ['12290', '3807302', 'No', '7', '60', 'E2', '0', '0', '0', 'No', 'No', 'Female', 'Direct', '3', 'L002', '600020', '34', '2', 'D7']
# ['12291', '3808142', 'No', '1', '30', 'E1', '71.43', '42.86', '-16.67', 'No', 'No', 'Male', 'Direct', '2', 'L001', '201301', '34', '2', 'D5']
# ['12294', '3815009', 'No', '5', '0', 'E3', '9.68', '9.68', '0', 'No', 'Yes', 'Male', 'Employee Referral', '5', 'L002', '600020', '34', '2', 'D11']
# ['12295', '3815263', 'No', '2', '0', 'E1', '25', '25', '0', 'No', 'No', 'Male', 'Direct', '1', 'L002', '600020', '34', '2', 'D3']
# ['12304', '3821185', 'No', '2', '0', 'E1', '49.07', '42.59', '-4.35', 'No', 'No', 'Male', 'Agency', '5', 'L001', '201301', '34', '1', 'D15']
# ['12305', '3821706', 'No', '1', '30', 'E1', '96.85', '75.2', '-11', 'No', 'No', 'Male', 'Agency', '4', 'L008', '411002', '34', '1', 'D15']
# ['12309', '3822084', 'No', '0', '30', 'E1', '50', '50', '0', 'No', 'No', 'Female', 'Agency', '4', 'L002', '600020', '34', '2', 'D20']
# ['12319', '3822427', 'No', '4', '0', 'E1', '191.67', '191.67', '0', 'No', 'No', 'Male', 'Employee Referral', '1', 'L002', '600020', '34', '1', 'D21']
# ['12327', '3828206', 'Yes', '2', '0', 'E1', '150', '150', '0', 'No', 'No', 'Female', 'Direct', '3', 'L002', '600020', '34', '4', 'D9']
# ['12331', '3834159', 'No', '0', '0', 'E2', '35.42', '35.42', '0', 'No', 'No', 'Male', 'Direct', '5', 'L001', '201301', '34', '2', 'D18']
# ['12332', '3835433', 'No', '0', '30', 'E1', '76.92', '53.85', '-13.04', 'No', 'No', 'Male', 'Direct', '4', 'L001', '201301', '34', '2', 'D2']
# ['12333', '3836076', 'No', '2', '0', 'E1', '45.25', '14.09', '-21.45', 'No', 'No', 'Female', 'Employee Referral', '1', 'L002', '600020', '34', '2', 'D3']

# %%
    #Reading Lob_Master
        with open('LOB_Master.csv', 'r') as file_to_read:
                    data = csv.reader(file_to_read)
                    for i in data:
                        print(i)
# Out:
# ['LOB_Id', 'LOB', 'Description']
# ['1', 'ERS', 'ERS typically stands for "Enterprise Resource Services"']
# ['2', 'INFRA', 'INFRA often represents "Infrastructure']
# ['3', 'Healthcare', 'The Healthcare LOB likely relates to services and operations ']
# ['4', 'BFSI', ' BFSI stands for "Banking, Financial Services, and Insurance.']
# ['5', 'CSMP', 'The meaning of CSMP is not widely recognized']
# ['6', 'ETS', 'ETS could refer to "Enterprise Technology Services']
# ['7', 'AXON', 'The term AXON is not specific enough to provide a detailed description']
# ['8', 'EAS', 'EAS may stand for "Enterprise Application Services']
# ['9', 'MMS', 'MMS could represent "Managed Mobility Services']

# %%
#writing data in LOB file

fields = ['LOB_Id', 'LOB', 'Description']

data = [
    [1, 'ERS', 'ERS typically stands for "Enterprise Resource Services"'],
    [2, 'INFRA', 'INFRA often represents "Infrastructure'],
    [3, 'Healthcare', 'The Healthcare LOB likely relates to services and operations '],
    [4, 'BFSI', ' BFSI stands for "Banking, Financial Services, and Insurance.'],
    [5, 'CSMP', 'The meaning of CSMP is not widely recognized'],
    [6, 'ETS', 'ETS could refer to "Enterprise Technology Services'],
    [7, 'AXON', 'The term AXON is not specific enough to provide a detailed description'],
    [8, 'EAS', 'EAS may stand for "Enterprise Application Services'],
    [9, 'MMS', 'MMS could represent "Managed Mobility Services']
]
with open('LOB_Master.csv', 'w') as file_to_write:
 exec = csv.writer(file_to_write)
 exec.writerow(fields)
 exec.writerows(data)
with open('LOB_Master.csv', 'r') as file_to_read:
        data = csv.reader(file_to_read)
        for i in data:
         print(i)
# Out:
# ['LOB_Id', 'LOB', 'Description']
# ['1', 'ERS', 'ERS typically stands for "Enterprise Resource Services"']
# ['2', 'INFRA', 'INFRA often represents "Infrastructure']
# ['3', 'Healthcare', 'The Healthcare LOB likely relates to services and operations ']
# ['4', 'BFSI', ' BFSI stands for "Banking, Financial Services, and Insurance.']
# ['5', 'CSMP', 'The meaning of CSMP is not widely recognized']
# ['6', 'ETS', 'ETS could refer to "Enterprise Technology Services']
# ['7', 'AXON', 'The term AXON is not specific enough to provide a detailed description']
# ['8', 'EAS', 'EAS may stand for "Enterprise Application Services']
# ['9', 'MMS', 'MMS could represent "Managed Mobility Services']

# %%
# Difining value to file 

Lob=pd.read_csv('LOB_Master.csv')
print(Lob)
Joining=pd.read_csv('Joining_Status.csv')
print(Joining)
Hr=pd.read_csv('HR_Hiring_details_transaction.csv')
print(Hr)
# Joining(concating files)
concate_date = pd.concat([Lob,Joining])
concate_date.head()
concate_date1 = pd.merge(Hr, Joining, on='Candidate_Ref', how='inner')
concate_date.head()
concate_date2 = pd.merge(Lob, concate_date1, on='LOB_Id', how='inner')
concate_date2.head()
# Out:
#    LOB_Id         LOB                                        Description
# 0       1         ERS  ERS typically stands for "Enterprise Resource ...
# 1       2       INFRA             INFRA often represents "Infrastructure
# 2       3  Healthcare  The Healthcare LOB likely relates to services ...
# 3       4        BFSI   BFSI stands for "Banking, Financial Services,...
# 4       5        CSMP       The meaning of CSMP is not widely recognized
# 5       6         ETS  ETS could refer to "Enterprise Technology Serv...
# 6       7        AXON  The term AXON is not specific enough to provid...
# 7       8         EAS  EAS may stand for "Enterprise Application Serv...
# 8       9         MMS     MMS could represent "Managed Mobility Services
#       Candidate_Ref  Status
# 0           2110407  Joined
# 1           2112635  Joined
# 2           2112838  Joined
# 3           2115021  Joined
# 4           2115125  Joined
# ...             ...     ...
# 8990        3822427  Joined
# 8991        3828206  Joined
# 8992        3834159  Joined
# 8993        3835433  Joined
# 8994        3836076  Joined
#
# [8995 rows x 2 columns]
#         Sno  Candidate_Ref DOJ_Extended  Duration_to_accept_offer  \
# 0         1        2110407          Yes                        14
# 1         2        2112635           No                        18
# 2         3        2112838           No                         3
# 3         4        2115021           No                        26
# 4         5        2115125          Yes                         1
# ...     ...            ...          ...                       ...
# 8990  12319        3822427           No                         4
# 8991  12327        3828206          Yes                         2
# 8992  12331        3834159           No                         0
# 8993  12332        3835433           No                         0
# 8994  12333        3836076           No                         2
#
#       Notice_Period Offered_Band  ected_in_CTCPercent_hike_exp  \
# 0                30           E2                        -20.79
# 1                30           E2                         50.00
# 2                45           E2                         42.84
# 3                30           E2                         42.84
# 4               120           E2                         42.59
# ...             ...          ...                           ...
# 8990              0           E1                        191.67
# 8991              0           E1                        150.00
# 8992              0           E2                         35.42
# 8993             30           E1                         76.92
# 8994              0           E1                         45.25
#
#       Percent_hike_offered_in_CTC  Percent_difference_CTC Joining_Bonus  \
# 0                           13.16                   42.86            No
# 1                          320.00                  180.00            No
# 2                           42.84                    0.00            No
# 3                           42.84                    0.00            No
# 4                           42.59                    0.00            No
# ...                           ...                     ...           ...
# 8990                       191.67                    0.00            No
# 8991                       150.00                    0.00            No
# 8992                        35.42                    0.00            No
# 8993                        53.85                  -13.04            No
# 8994                        14.09                  -21.45            No
#
#      Candidate_relocate_actual  Gender   Candidate_Source  Rex_in_Yrs  \
# 0                           No  Female             Agency           7
# 1                           No    Male  Employee Referral           8
# 2                           No    Male             Agency           4
# 3                           No    Male  Employee Referral           4
# 4                          Yes    Male  Employee Referral           6
# ...                        ...     ...                ...         ...
# 8990                        No    Male  Employee Referral           1
# 8991                        No  Female             Direct           3
# 8992                        No    Male             Direct           5
# 8993                        No    Male             Direct           4
# 8994                        No  Female  Employee Referral           1
#
#      Location_ID  Postal_Code   Age  LOB_Id Domicile_Id
# 0           L001       201301  34.0       1          D6
# 1           L002       600020  34.0       2          D9
# 2           L001       201301  27.0       2         D10
# 3           L001       201301  34.0       2          D3
# 4           L001       201301  34.0       2         D21
# ...          ...          ...   ...     ...         ...
# 8990        L002       600020  34.0       1         D21
# 8991        L002       600020  34.0       4          D9
# 8992        L001       201301  34.0       2         D18
# 8993        L001       201301  34.0       2          D2
# 8994        L002       600020  34.0       2          D3
#
# [8995 rows x 19 columns]
#    LOB_Id  LOB                                        Description  Sno  \
# 0       1  ERS  ERS typically stands for "Enterprise Resource ...    1
# 1       1  ERS  ERS typically stands for "Enterprise Resource ...   22
# 2       1  ERS  ERS typically stands for "Enterprise Resource ...   24
# 3       1  ERS  ERS typically stands for "Enterprise Resource ...   29
# 4       1  ERS  ERS typically stands for "Enterprise Resource ...   32
#
#    Candidate_Ref DOJ_Extended  Duration_to_accept_offer  Notice_Period  \
# 0        2110407          Yes                        14             30
# 1        2175237           No                         7             30
# 2        2184108           No                         0             30
# 3        2205496          Yes                        32            120
# 4        2214217           No                         4             30
#
#   Offered_Band  ected_in_CTCPercent_hike_exp  ...  Joining_Bonus  \
# 0           E2                        -20.79  ...             No
# 1           E1                        221.43  ...             No
# 2           E1                         37.50  ...             No
# 3           E3                         50.97  ...             No
# 4           E2                         -2.17  ...             No
#
#    Candidate_relocate_actual  Gender   Candidate_Source Rex_in_Yrs  \
# 0                         No  Female             Agency          7
# 1                         No    Male             Direct          2
# 2                         No  Female  Employee Referral          3
# 3                         No    Male             Direct         13
# 4                         No  Female  Employee Referral          5
#
#   Location_ID  Postal_Code   Age  Domicile_Id  Status
# 0        L001       201301  34.0           D6  Joined
# 1        L001       201301  34.0          D21  Joined
# 2        L002       600020  30.0          D19  Joined
# 3        L002       600020  40.0           D9  Joined
# 4        L002       600020  33.0          D24  Joined
#
# [5 rows x 22 columns]

# %%
# Graph function

fh = pd.read_csv('Joining_Status.csv')
print(fh.head(6000))


joined = fh[fh['Status'] == 'Joined']
not_joined = fh[fh['Status'] == 'Not joined']

joined_count = len(joined)
not_joined_count = len(not_joined)


labels = ['Joined', 'Not joined']
counts = [joined_count, not_joined_count]

plt.bar(labels, counts, color='red')
plt.xlabel('Status')
plt.ylabel('Number of Candidates')
plt.title('Joined vs. Not joined')
plt.show()
# Out:
#       Candidate_Ref      Status
# 0           2110407      Joined
# 1           2112635      Joined
# 2           2112838      Joined
# 3           2115021      Joined
# 4           2115125      Joined
# ...             ...         ...
# 5995        3234832      Joined
# 5996        3234857      Joined
# 5997        3234859  Not Joined
# 5998        3234871      Joined
# 5999        3234884      Joined
#
# [6000 rows x 2 columns]

# %%
# Using min function by numpy

Min_diffrence_hike= Hr['Percent_difference_CTC'].min()
Min_offered_hike= Hr['Percent_hike_offered_in_CTC'].min()
Diff_in_CTC= Hr['Percent_difference_CTC'].min()
print('Minimum difference hike in percentage: ', Min_diffrence_hike)
print('Minimum expected hike in percentage: ', Min_offered_hike)
print('Differce in CTC: ', Diff_in_CTC)
# Out:
# Minimum difference hike in percentage:  -67.27
# Minimum expected hike in percentage:  -60.53
# Differce in CTC:  -67.27

# %%
# Using Max function by numpy


Max_expected_hike= Hr['Percent_difference_CTC'].max()
Max_offered_hike= Hr['Percent_hike_offered_in_CTC'].max()

print('Maximum expected hike in percentage: ', Max_expected_hike)
print('Maximum offered  hike in percentage: ',Max_offered_hike)
# Out:
# Maximum expected hike in percentage:  300.0
# Maximum offered  hike in percentage:  471.43
